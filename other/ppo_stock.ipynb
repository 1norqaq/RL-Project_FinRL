# %% [markdown]
# # PPO Agent Training and Testing for Stock Portfolio Management
#
# This notebook implements a Proximal Policy Optimization (PPO) agent for automated stock trading with rolling window backtesting strategy. The agent is trained on DOW-30 stocks with technical indicators and tested against the Dow Jones Index benchmark.
#
# ## Overview
# - **Data**: DOW-30 stocks from Yahoo Finance
# - **Agent**: Proximal Policy Optimization (PPO) via ElegantRL
# - **Environment**: StockTradingEnv with transaction costs
# - **Validation**: Rolling window approach (252-day training, 20-day validation/test periods)
# - **Benchmark**: Dow Jones Index

# %%
import os
import pandas as pd
import numpy as np
import torch
import yfinance as yf
import gymnasium as gym

# Patch torch.load to allow loading models without weights_only=True
if not hasattr(torch, '_original_load'):
    torch._original_load = torch.load

def patched_torch_load(*args, **kwargs):
    kwargs.setdefault('weights_only', False)
    return torch._original_load(*args, **kwargs)

torch.load = patched_torch_load

# Patch yf.download to remove proxy parameter
if not hasattr(yf, '_original_download'):
    yf._original_download = yf.download

def patched_download(*args, **kwargs):
    kwargs.pop('proxy', None)
    return yf._original_download(*args, **kwargs)

yf.download = patched_download

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from elegantrl.agents import AgentPPO
from elegantrl.train.run import train_agent
from env_wrapper.ppo_env_wrapper import ElegantFinRLWrapper

try:
    from elegantrl.train.config import Config as Arguments
except ImportError:
    from elegantrl.train.config import Arguments

print("[✓] All imports successful!")
# Out:
# [✓] All imports successful!

# %%
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.preprocessors import FeatureEngineer

def prepare_data(cache_file = "./data/stock_dow30_cache.csv",
        TRAIN_START_DATE = '2010-01-01',
        TEST_END_DATE = '2023-12-30'):
    """
    Load stock data from cache or download from Yahoo Finance.
    Returns preprocessed dataframe with technical indicators.
    """
    
    # Create data directory if it doesn't exist
    os.makedirs(os.path.dirname(cache_file), exist_ok=True)
    
    if os.path.exists(cache_file):
        print(f"[INFO] Loading validated cache '{cache_file}'...")
        try:
            df = pd.read_csv(cache_file)
            df = df.drop_duplicates(subset=['date', 'tic'])
            if len(df) > 0:
                print(f"[✓] Cache loaded: {len(df)} records, Date range: {df['date'].min()} to {df['date'].max()}")
                return df
            else:
                print("[!] Cache file is empty, will re-download...")
        except Exception as e:
            print(f"[!] Error loading cache: {e}, will re-download...")

    
    else:
        df = YahooDownloader(start_date=TRAIN_START_DATE,
                            end_date=TEST_END_DATE,
                            ticker_list=DOW_30_TICKER).fetch_data()


        print(f"[✓] Data preparation complete!")
        print(f"    - Total records: {len(df)}")
        print(f"    - Date range: {df['date'].min()} to {df['date'].max()}")
        print(f"    - Unique tickers: {df['tic'].nunique()}")
        # print(f"    - Complete dates: {len(valid_dates)}")

        # Add technical indicators
        print("\n[STEP 2.5] Calculating technical indicators...")

        # Define indicators to calculate
        TECHNICAL_INDICATORS = ["macd", "boll_ub", "boll_lb", "rsi_30", "cci_30", "dx_30", "close_30_sma", "close_60_sma"]

        try:
            fe = FeatureEngineer(
                use_technical_indicator=True,
                tech_indicator_list=TECHNICAL_INDICATORS,
                use_vix=False,
                use_turbulence=False,
                user_defined_feature=False
            )
            
            df = fe.preprocess_data(df)
            
            # Rename close_30_sma and close_60_sma to match expected names
            if 'close_30_sma' in df.columns:
                df = df.rename(columns={'close_30_sma': 'close_30'})
            if 'close_60_sma' in df.columns:
                df = df.rename(columns={'close_60_sma': 'close_60'})
            
            print(f"[✓] Technical indicators calculated!")
            print(f"    Available columns: {df.columns.tolist()}")
            
        except Exception as e:
            print(f"[!] Error calculating technical indicators: {e}")
            print(f"[!] Attempting alternative method...")
            
            # Alternative: Calculate indicators manually using ta library
            import ta
            
            df_list = []
            for ticker in df['tic'].unique():
                ticker_df = df[df['tic'] == ticker].copy()
                ticker_df = ticker_df.sort_values('date')
                
                # Calculate indicators
                ticker_df['macd'] = ta.trend.macd_diff(ticker_df['close'])
                
                bb = ta.volatility.BollingerBands(ticker_df['close'])
                ticker_df['boll_ub'] = bb.bollinger_hband()
                ticker_df['boll_lb'] = bb.bollinger_lband()
                
                ticker_df['rsi_30'] = ta.momentum.rsi(ticker_df['close'], window=30)
                ticker_df['cci_30'] = ta.trend.cci(ticker_df['high'], ticker_df['low'], ticker_df['close'], window=30)
                ticker_df['dx_30'] = ta.trend.adx(ticker_df['high'], ticker_df['low'], ticker_df['close'], window=30)
                ticker_df['close_30'] = ticker_df['close'].rolling(window=30).mean()
                ticker_df['close_60'] = ticker_df['close'].rolling(window=60).mean()
                
                df_list.append(ticker_df)
            
            df = pd.concat(df_list, ignore_index=True)
            df = df.dropna()  # Remove rows with NaN from indicator calculation
            
            print(f"[✓] Technical indicators calculated using ta library!")

        if df is not None and not df.empty:
            df.to_csv(cache_file, index=False)
            print(f"[✓] Data saved to cache: {cache_file}")
        else:
            print("[ERROR] Failed to download data or received empty dataframe")
            return None
    
    return df

def split_train_test(df,
            TRAIN_START_DATE = '2010-01-07',
            TRAIN_END_DATE = '2023-10-24',
            TEST_START_DATE1 = '2023-10-25',
            TEST_END_DATE1 = '2023-11-14',
            TEST_START_DATE2 = '2023-11-15',
            TEST_END_DATE2 = '2023-11-22'):

    df['date'] = pd.to_datetime(df['date'])

    df_train = df[
        (df['date'] >= TRAIN_START_DATE) &
        (df['date'] <= TRAIN_END_DATE)
    ].copy()

    df_test1 = df[
        (df['date'] >= TEST_START_DATE1) &
        (df['date'] <= TEST_END_DATE1)
    ].copy()

    df_test2 = df[
        (df['date'] >= TEST_START_DATE2) &
        (df['date'] <= TEST_END_DATE2)
    ].copy()

    print(f"[INFO] Train: {df_train['date'].min()} → {df_train['date'].max()}, "
          f"{len(df_train)} rows")

    return df_train, df_test1, df_test2

# Load data
print("\n[STEP 1] Loading stock data...")
df = prepare_data()
df_train, df_test1, df_test2 = split_train_test(df)
# Out:
# [STEP 1] Loading stock data...
# [INFO] Loading validated cache './data/stock_dow30_cache.csv'...
# [✓] Cache loaded: 29174 records, Date range: 2020-01-02 to 2023-12-29
# [INFO] Train: 2020-01-02 00:00:00 → 2023-10-24 00:00:00, 27840 rows

# %%
print(df_train.head())
# Out:
#         date       close        high         low        open     volume   tic  \
# 0 2020-01-02   72.400505   72.460769   71.156667   71.409770  135480400  AAPL
# 1 2020-01-02  198.233841  200.785036  197.309126  200.628164    2088000  AMGN
# 2 2020-01-02  116.380058  116.768453  114.881964  115.279608    2708000   AXP
# 3 2020-01-02  331.348572  331.378393  325.761816  326.606765    4544400    BA
# 4 2020-01-02  132.564758  132.582375  130.319089  131.217360    3311900   CAT
#
#    day      macd   boll_ub   boll_lb    rsi_30   cci_30     dx_30  close_30  \
# 0    3 -0.103588 -0.882459 -0.800992 -5.695718 -0.69721  4.541098 -0.842867
# 1    3 -0.103588 -0.882459 -0.800992 -5.695718 -0.69721  4.541098  0.562664
# 2    3 -0.103588 -0.882459 -0.800992 -5.695718 -0.69721  4.541098 -0.351625
# 3    3 -0.103588 -0.882459 -0.800992 -5.695718 -0.69721  4.541098  2.049527
# 4    3 -0.103588 -0.882459 -0.800992 -5.695718 -0.69721  4.541098 -0.170845
#
#    close_60
# 0 -0.843590
# 1  0.575064
# 2 -0.347762
# 3  2.075809
# 4 -0.165294

# %%
# Training and Testing with Full Dataset
import warnings
warnings.filterwarnings('ignore')

ALL_INDICATORS = ["macd", "boll_ub", "boll_lb", "rsi_30", "cci_30", "dx_30", "close_30", "close_60"]

# Prepare training data
stock_dimension = len(df_train['tic'].unique()) # Number of unique stocks in training data
state_dim = 1 + stock_dimension * (len(ALL_INDICATORS) + 2) # State dimension: cash + (stock_dim * (indicators + price + shares))

# Create day indices for training data
train_dates = sorted(df_train['date'].unique())
date_map_train = {date: idx for idx, date in enumerate(train_dates)}
df_train['day'] = df_train['date'].map(date_map_train) # Map dates to day indices for training data
df_train.set_index('day', inplace=True, drop=False)

# Create day indices for test data
test_dates1 = sorted(df_test1['date'].unique())
date_map_test1 = {date: idx for idx, date in enumerate(test_dates1)}
df_test1['day'] = df_test1['date'].map(date_map_test1) # Map dates to day indices for test data
df_test1.set_index('day', inplace=True, drop=False)

test_dates2 = sorted(df_test2['date'].unique())
date_map_test2 = {date: idx for idx, date in enumerate(test_dates2)}
df_test2['day'] = df_test2['date'].map(date_map_test2) # Map dates to day indices for test data
df_test2.set_index('day', inplace=True, drop=False)

print(f"[INFO] Stock dimension: {stock_dimension}")
print(f"[INFO] State dimension: {state_dim}")
print(f"[INFO] Training data shape: {df_train.shape}")
print(f"[INFO] Test data 1 shape: {df_test1.shape}")
print(f"[INFO] Test data 2 shape: {df_test2.shape}")
# Out:
# [INFO] Stock dimension: 29
# [INFO] State dimension: 291
# [INFO] Training data shape: (27840, 16)
# [INFO] Test data 1 shape: (435, 16)
# [INFO] Test data 2 shape: (174, 16)

# %%
def setup_ppo_args(env_args, cwd_path):
    args = Arguments(agent_class=AgentPPO, env_class=ElegantFinRLWrapper)
    args.env_args = env_args
    args.env_name = env_args['env_name']

    args.net_dims = (128, 64)
    args.state_dim = env_args['state_dim']
    args.action_dim = env_args['action_dim']
    args.if_discrete = env_args['if_discrete']

    args.learning_rate = 1e-4
    args.batch_size = 128

    args.target_step = 2000
    args.break_step = 40000

    # Training progress and logging
    args.worker_num = 1
    args.eval_proc_num = 0
    args.if_use_multi_processing = False
    args.eval_gap = 500  # Evaluate every 500 steps to see progress
    args.save_gap = 200  # Save checkpoint every 200 steps
    
    # Enable verbose output for monitoring
    args.if_save = True
    args.if_overwrite_save = True

    args.cwd = cwd_path
    args.if_remove = False  # Keep old checkpoints for comparison
    return args

print("[✓] setup_ppo_args function defined!")
# Out:
# [✓] setup_ppo_args function defined!

# %%
def real_test_inference(test_df, stock_dim, indicators, args, env_params):
    # print(env_params)
    env_params["df"] = test_df

    env = ElegantFinRLWrapper(**env_params)

    agent = AgentPPO(args.net_dims, args.state_dim, args.action_dim)
    agent.save_or_load_agent(args.cwd, if_save=False)
    agent.act.eval()

    res = env.reset()
    state = res[0] if isinstance(res, tuple) else res

    done = False
    while not done:
        s_tensor = torch.as_tensor((state,), dtype=torch.float32, device=agent.device)
        with torch.no_grad():
            action = agent.act(s_tensor).detach().cpu().numpy()[0] # action shape: (action_dim,), which indicates the amount to buy/sell for each stock
        # print(f"Action taken: {action}")
        step_res = env.step(action)
        if len(step_res) == 5:
            state, reward, term, trunc, _ = step_res
            done = term or trunc
        else:
            state, reward, done, _, _ = step_res

    return env.env.save_asset_memory()

print("[✓] real_test_inference function defined!")
# Out:
# [✓] real_test_inference function defined!

# %%
# Setup environment parameters for training
env_params = {
    "env_name": "FinRL_PPO_Train",
    "df": df_train,
    "stock_dim": stock_dimension,
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": [0] * stock_dimension,
    "buy_cost_pct": [0.001] * stock_dimension,
    "sell_cost_pct": [0.001] * stock_dimension,
    "reward_scaling": 3e-4,
    "state_space": state_dim,
    "action_space": stock_dimension,
    "tech_indicator_list": ALL_INDICATORS,
    "state_dim": state_dim,
    "action_dim": stock_dimension,
    "if_discrete": False,
    "target_return": 10.0
}
print(f"\n[STEP 6] Starting PPO Agent Training on Full Dataset...")
print(f"Training period: {df_train['date'].min()} to {df_train['date'].max()}")
print("\n" + "="*80)

try:
    cwd_path = "./checkpoints/stock/ppo_full_train"
    os.makedirs(cwd_path, exist_ok=True)

    args = setup_ppo_args(env_params, cwd_path)

    print(f"\n[Training Configuration]")
    print(f"  Network Dims: {args.net_dims}")
    print(f"  Learning Rate: {args.learning_rate}")
    print(f"  Batch Size: {args.batch_size}")
    print(f"  Target Steps per Update: {args.target_step}")
    print(f"  Total Training Steps: {args.break_step}")
    print(f"  Evaluation Gap: {args.eval_gap} steps")
    print(f"  Checkpoint Path: {cwd_path}")
    print("="*80 + "\n")
    
    print("[-->] Starting PPO Agent Training...")
    
    train_agent(args)
    
    print("\n" + "="*80)
    print("[✓] Training completed successfully!")
    print("="*80)

    # Run inference on test data
    print(f"\n[STEP 6.5] Running inference on test data...")
    test_results1 = real_test_inference(df_test1, stock_dimension, ALL_INDICATORS, args, env_params)
    test_results2 = real_test_inference(df_test2, stock_dimension, ALL_INDICATORS, args, env_params)
    
    log_path = "./logs/stock/"
    os.makedirs(log_path, exist_ok=True)
    # Save test results
    test_results1.to_csv(log_path + "ppo_test_results1.csv", index=False)
    test_results2.to_csv(log_path + "ppo_test_results2.csv", index=False)
    print(f"[✓] Test results saved")
    
    # Calculate and display initial performance metrics
    initial_value1 = test_results1['account_value'].iloc[0]
    final_value1 = test_results1['account_value'].iloc[-1]
    total_return1 = (final_value1 / initial_value1 - 1) * 100

    print(f"    2023-10-25~2023-11-14: Initial Portfolio Value: ${initial_value1:,.2f}")
    print(f"    2023-10-25~2023-11-14: Final Portfolio Value: ${final_value1:,.2f}")
    print(f"    2023-10-25~2023-11-14: Total Return: {total_return1:.2f}%")

    initial_value2 = test_results2['account_value'].iloc[0]
    final_value2 = test_results2['account_value'].iloc[-1]
    total_return2 = (final_value2 / initial_value2 - 1) * 100
    print(f"    2023-11-15~2023-11-22: Initial Portfolio Value: ${initial_value2:,.2f}")
    print(f"    2023-11-15~2023-11-22: Final Portfolio Value: ${final_value2:,.2f}")
    print(f"    2023-11-15~2023-11-22: Total Return: {total_return2:.2f}%")

except Exception as e:
    print(f"[ERROR] Training failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [STEP 6] Starting PPO Agent Training on Full Dataset...
# Training period: 2020-01-02 00:00:00 to 2023-10-24 00:00:00
#
# ================================================================================
#
# [Training Configuration]
#   Network Dims: (128, 64)
#   Learning Rate: 0.0001
#   Batch Size: 128
#   Target Steps per Update: 2000
#   Total Training Steps: 40000
#   Evaluation Gap: 500 steps
#   Checkpoint Path: ./checkpoints/stock/ppo_full_train
# ================================================================================
#
# [-->] Starting PPO Agent Training...
# | train_agent_multiprocessing() with GPU_ID 0
# | Arguments Keep cwd: ./checkpoints/stock/ppo_full_train
# [✓] PPO Environment Wrappers imported successfully
# [✓] FastContinuousCryptoEnv & ElegantFinRLWrapper classes defined!
# [✓] PPO Environment Wrappers imported successfully
# [✓] FastContinuousCryptoEnv & ElegantFinRLWrapper classes defined!
# [DEBUG] Step Reward: -0.4441, Action Penalty: 1.4500, Total Reward: -1.8941
# [DEBUG] Step Reward: 0.2409, Action Penalty: 0.0000, Total Reward: 0.2409
# [DEBUG] Step Reward: -0.7383, Action Penalty: 0.0000, Total Reward: -0.7383
# [DEBUG] Step Reward: 1.8153, Action Penalty: 0.0000, Total Reward: 1.8153
# [DEBUG] Step Reward: 1.4893, Action Penalty: 0.0000, Total Reward: 1.4893
# [DEBUG] Step Reward: -0.9892, Action Penalty: 0.0000, Total Reward: -0.9892
# [DEBUG] Step Reward: -0.4043, Action Penalty: 0.0000, Total Reward: -0.4043
# [DEBUG] Step Reward: 0.5612, Action Penalty: 0.1625, Total Reward: 0.3987
# [DEBUG] Step Reward: 1.3171, Action Penalty: 1.2734, Total Reward: 0.0438
# [DEBUG] Step Reward: 3.9790, Action Penalty: 0.7135, Total Reward: 3.2654
# [DEBUG] Step Reward: 1.2107, Action Penalty: 0.8030, Total Reward: 0.4077
# [DEBUG] Step Reward: -0.5702, Action Penalty: 0.8098, Total Reward: -1.3800
# [DEBUG] Step Reward: 0.7325, Action Penalty: 0.5927, Total Reward: 0.1398
# [DEBUG] Step Reward: -1.3947, Action Penalty: 0.6169, Total Reward: -2.0116
# [DEBUG] Step Reward: -2.6791, Action Penalty: 0.7243, Total Reward: -3.4034
# [DEBUG] Step Reward: -5.3244, Action Penalty: 0.6263, Total Reward: -5.9506
# [DEBUG] Step Reward: 3.7315, Action Penalty: 0.5721, Total Reward: 3.1595
# [DEBUG] Step Reward: -1.1162, Action Penalty: 0.5954, Total Reward: -1.7115
# [DEBUG] Step Reward: 0.5389, Action Penalty: 0.6510, Total Reward: -0.1121
# [DEBUG] Step Reward: -6.2024, Action Penalty: 0.4802, Total Reward: -6.6825
# [DEBUG] Step Reward: 1.8201, Action Penalty: 0.6193, Total Reward: 1.2008
# [DEBUG] Step Reward: 5.1444, Action Penalty: 0.3568, Total Reward: 4.7876
# [DEBUG] Step Reward: 7.6762, Action Penalty: 0.5238, Total Reward: 7.1523
# [DEBUG] Step Reward: -0.6458, Action Penalty: 0.5467, Total Reward: -1.1924
# [DEBUG] Step Reward: -3.6852, Action Penalty: 0.4103, Total Reward: -4.0955
# [DEBUG] Step Reward: 0.5689, Action Penalty: 0.5612, Total Reward: 0.0077
# [DEBUG] Step Reward: 0.8782, Action Penalty: 0.6787, Total Reward: 0.1995
# [DEBUG] Step Reward: 4.1739, Action Penalty: 0.6169, Total Reward: 3.5570
# [DEBUG] Step Reward: -0.6768, Action Penalty: 0.2888, Total Reward: -0.9656
# [DEBUG] Step Reward: -1.4440, Action Penalty: 0.5375, Total Reward: -1.9815
# [DEBUG] Step Reward: -2.2277, Action Penalty: 0.4574, Total Reward: -2.6852
# [DEBUG] Step Reward: 2.6094, Action Penalty: 0.4468, Total Reward: 2.1625
# [DEBUG] Step Reward: -2.1983, Action Penalty: 0.6080, Total Reward: -2.8062
# [DEBUG] Step Reward: -2.3067, Action Penalty: 0.2908, Total Reward: -2.5975
# [DEBUG] Step Reward: -12.0510, Action Penalty: 0.3321, Total Reward: -12.3831
# [DEBUG] Step Reward: -10.0802, Action Penalty: 0.3277, Total Reward: -10.4079
# [DEBUG] Step Reward: -0.6868, Action Penalty: 0.3806, Total Reward: -1.0673
# [DEBUG] Step Reward: -12.8279, Action Penalty: 0.3998, Total Reward: -13.2277
# [DEBUG] Step Reward: -4.2156, Action Penalty: 0.3415, Total Reward: -4.5572
# [DEBUG] Step Reward: 14.9297, Action Penalty: 0.4739, Total Reward: 14.4558
# [DEBUG] Step Reward: -9.7848, Action Penalty: 0.3129, Total Reward: -10.0977
# [DEBUG] Step Reward: 14.1605, Action Penalty: 0.2722, Total Reward: 13.8883
# [DEBUG] Step Reward: -9.3937, Action Penalty: 0.2811, Total Reward: -9.6748
# [DEBUG] Step Reward: -4.5228, Action Penalty: 0.3813, Total Reward: -4.9040
# [DEBUG] Step Reward: -21.6447, Action Penalty: 0.3684, Total Reward: -22.0131
# [DEBUG] Step Reward: 12.8214, Action Penalty: 0.2800, Total Reward: 12.5414
# [DEBUG] Step Reward: -11.6931, Action Penalty: 0.3183, Total Reward: -12.0114
# [DEBUG] Step Reward: -24.3471, Action Penalty: 0.4235, Total Reward: -24.7706
# [DEBUG] Step Reward: 26.4691, Action Penalty: 0.3218, Total Reward: 26.1473
# [DEBUG] Step Reward: -32.6547, Action Penalty: 0.3534, Total Reward: -33.0080
# [DEBUG] Step Reward: 14.0506, Action Penalty: 0.3627, Total Reward: 13.6879
# [DEBUG] Step Reward: -16.0469, Action Penalty: 0.3220, Total Reward: -16.3689
# [DEBUG] Step Reward: 0.5975, Action Penalty: 0.4658, Total Reward: 0.1316
# [DEBUG] Step Reward: -11.3305, Action Penalty: 0.3578, Total Reward: -11.6884
# [DEBUG] Step Reward: -7.2102, Action Penalty: 0.2807, Total Reward: -7.4909
# [DEBUG] Step Reward: 22.0928, Action Penalty: 0.2835, Total Reward: 21.8093
# [DEBUG] Step Reward: 4.6330, Action Penalty: 0.2706, Total Reward: 4.3624
# [DEBUG] Step Reward: 15.1373, Action Penalty: 0.3107, Total Reward: 14.8265
# [DEBUG] Step Reward: -11.4526, Action Penalty: 0.2757, Total Reward: -11.7283
# [DEBUG] Step Reward: 8.6709, Action Penalty: 0.2846, Total Reward: 8.3863
# [DEBUG] Step Reward: -3.5496, Action Penalty: 0.3014, Total Reward: -3.8510
# [DEBUG] Step Reward: -11.7210, Action Penalty: 0.2260, Total Reward: -11.9470
# [DEBUG] Step Reward: 6.1601, Action Penalty: 0.3458, Total Reward: 5.8143
# [DEBUG] Step Reward: -5.0830, Action Penalty: 0.1703, Total Reward: -5.2533
# [DEBUG] Step Reward: 16.8408, Action Penalty: 0.2019, Total Reward: 16.6389
# [DEBUG] Step Reward: 1.2760, Action Penalty: 0.3473, Total Reward: 0.9287
# [DEBUG] Step Reward: 11.3273, Action Penalty: 0.4155, Total Reward: 10.9119
# [DEBUG] Step Reward: 3.1155, Action Penalty: 0.4449, Total Reward: 2.6706
# [DEBUG] Step Reward: -3.3979, Action Penalty: 0.5135, Total Reward: -3.9114
# [DEBUG] Step Reward: 5.2618, Action Penalty: 0.3113, Total Reward: 4.9505
# [DEBUG] Step Reward: -2.0897, Action Penalty: 0.3201, Total Reward: -2.4098
# [DEBUG] Step Reward: 2.5234, Action Penalty: 0.3481, Total Reward: 2.1753
# [DEBUG] Step Reward: 3.8692, Action Penalty: 0.3059, Total Reward: 3.5633
# [DEBUG] Step Reward: -5.2032, Action Penalty: 0.3671, Total Reward: -5.5703
# [DEBUG] Step Reward: -7.8328, Action Penalty: 0.3101, Total Reward: -8.1429
# [DEBUG] Step Reward: 4.7999, Action Penalty: 0.1626, Total Reward: 4.6373
# [DEBUG] Step Reward: 2.0380, Action Penalty: 0.3330, Total Reward: 1.7050
# [DEBUG] Step Reward: 4.0544, Action Penalty: 0.4279, Total Reward: 3.6266
# [DEBUG] Step Reward: 3.4385, Action Penalty: 0.4387, Total Reward: 2.9998
# [DEBUG] Step Reward: -1.4139, Action Penalty: 0.2711, Total Reward: -1.6850
# [DEBUG] Step Reward: 5.4298, Action Penalty: 0.2136, Total Reward: 5.2162
# [DEBUG] Step Reward: -1.9323, Action Penalty: 0.4081, Total Reward: -2.3403
# [DEBUG] Step Reward: -6.9954, Action Penalty: 0.4316, Total Reward: -7.4270
# [DEBUG] Step Reward: 0.2534, Action Penalty: 0.4405, Total Reward: -0.1872
# [DEBUG] Step Reward: 3.0004, Action Penalty: 0.2815, Total Reward: 2.7189
# [DEBUG] Step Reward: -1.5014, Action Penalty: 0.3681, Total Reward: -1.8695
# [DEBUG] Step Reward: 1.2818, Action Penalty: 0.3377, Total Reward: 0.9441
# [DEBUG] Step Reward: 4.4021, Action Penalty: 0.3969, Total Reward: 4.0053
# [DEBUG] Step Reward: -0.8083, Action Penalty: 0.3479, Total Reward: -1.1562
# [DEBUG] Step Reward: -4.8758, Action Penalty: 0.4325, Total Reward: -5.3083
# [DEBUG] Step Reward: -6.0525, Action Penalty: 0.2965, Total Reward: -6.3490
# [DEBUG] Step Reward: 5.7635, Action Penalty: 0.3693, Total Reward: 5.3942
# [DEBUG] Step Reward: -0.7800, Action Penalty: 0.3097, Total Reward: -1.0897
# [DEBUG] Step Reward: 7.8830, Action Penalty: 0.4004, Total Reward: 7.4825
# [DEBUG] Step Reward: -3.3580, Action Penalty: 0.2926, Total Reward: -3.6506
# [DEBUG] Step Reward: 3.9180, Action Penalty: 0.3653, Total Reward: 3.5527
# [DEBUG] Step Reward: -2.4614, Action Penalty: 0.2365, Total Reward: -2.6979
# [DEBUG] Step Reward: 0.1026, Action Penalty: 0.4332, Total Reward: -0.3307
# [DEBUG] Step Reward: 7.2032, Action Penalty: 0.3590, Total Reward: 6.8442
# [DEBUG] Step Reward: 8.5380, Action Penalty: 0.4870, Total Reward: 8.0510
# [DEBUG] Step Reward: -2.6615, Action Penalty: 0.4979, Total Reward: -3.1594
# [DEBUG] Step Reward: -0.9783, Action Penalty: 0.2884, Total Reward: -1.2667
# [DEBUG] Step Reward: 1.5323, Action Penalty: 0.2889, Total Reward: 1.2435
# [DEBUG] Step Reward: 2.3189, Action Penalty: 0.3927, Total Reward: 1.9262
# [DEBUG] Step Reward: 4.7584, Action Penalty: 0.4978, Total Reward: 4.2606
# [DEBUG] Step Reward: -0.2155, Action Penalty: 0.3612, Total Reward: -0.5766
# [DEBUG] Step Reward: 8.4819, Action Penalty: 0.3545, Total Reward: 8.1274
# [DEBUG] Step Reward: 2.2993, Action Penalty: 0.2270, Total Reward: 2.0723
# [DEBUG] Step Reward: -1.3592, Action Penalty: 0.4530, Total Reward: -1.8122
# [DEBUG] Step Reward: -1.6127, Action Penalty: 0.4082, Total Reward: -2.0209
# [DEBUG] Step Reward: -20.3841, Action Penalty: 0.3145, Total Reward: -20.6986
# [DEBUG] Step Reward: 4.4184, Action Penalty: 0.3418, Total Reward: 4.0765
# [DEBUG] Step Reward: 2.5238, Action Penalty: 0.3939, Total Reward: 2.1299
# [DEBUG] Step Reward: 6.1651, Action Penalty: 0.4437, Total Reward: 5.7214
# [DEBUG] Step Reward: -2.2486, Action Penalty: 0.3613, Total Reward: -2.6099
# [DEBUG] Step Reward: -1.2430, Action Penalty: 0.1100, Total Reward: -1.3530
# [DEBUG] Step Reward: -1.4380, Action Penalty: 0.3060, Total Reward: -1.7440
# [DEBUG] Step Reward: 1.3582, Action Penalty: 0.3037, Total Reward: 1.0545
# [DEBUG] Step Reward: 2.4996, Action Penalty: 0.3314, Total Reward: 2.1682
# [DEBUG] Step Reward: -7.3922, Action Penalty: 0.3339, Total Reward: -7.7261
# [DEBUG] Step Reward: 5.7244, Action Penalty: 0.2753, Total Reward: 5.4491
# [DEBUG] Step Reward: -10.5010, Action Penalty: 0.2513, Total Reward: -10.7524
# [DEBUG] Step Reward: 4.3611, Action Penalty: 0.3014, Total Reward: 4.0597
# [DEBUG] Step Reward: 3.7903, Action Penalty: 0.4495, Total Reward: 3.3407
# [DEBUG] Step Reward: -0.7050, Action Penalty: 0.3580, Total Reward: -1.0630
# [DEBUG] Step Reward: 0.8262, Action Penalty: 0.4578, Total Reward: 0.3684
# [DEBUG] Step Reward: 6.2896, Action Penalty: 0.3324, Total Reward: 5.9572
# [DEBUG] Step Reward: -5.1384, Action Penalty: 0.3299, Total Reward: -5.4684
# [DEBUG] Step Reward: 3.0693, Action Penalty: 0.4258, Total Reward: 2.6435
# [DEBUG] Step Reward: -3.7806, Action Penalty: 0.2348, Total Reward: -4.0154
# [DEBUG] Step Reward: 4.5907, Action Penalty: 0.4038, Total Reward: 4.1869
# [DEBUG] Step Reward: 3.0403, Action Penalty: 0.5212, Total Reward: 2.5191
# [DEBUG] Step Reward: 5.7863, Action Penalty: 0.4635, Total Reward: 5.3228
# [DEBUG] Step Reward: 1.6027, Action Penalty: 0.4033, Total Reward: 1.1994
# [DEBUG] Step Reward: -0.3187, Action Penalty: 0.4567, Total Reward: -0.7754
# [DEBUG] Step Reward: -1.1552, Action Penalty: 0.4480, Total Reward: -1.6032
# [DEBUG] Step Reward: 0.9164, Action Penalty: 0.3809, Total Reward: 0.5355
# [DEBUG] Step Reward: 0.2732, Action Penalty: 0.3761, Total Reward: -0.1029
# [DEBUG] Step Reward: -0.0510, Action Penalty: 0.3913, Total Reward: -0.4423
# [DEBUG] Step Reward: -4.9271, Action Penalty: 0.3529, Total Reward: -5.2800
# [DEBUG] Step Reward: -4.4901, Action Penalty: 0.4320, Total Reward: -4.9221
# [DEBUG] Step Reward: 0.9956, Action Penalty: 0.3485, Total Reward: 0.6472
# [DEBUG] Step Reward: -1.8662, Action Penalty: 0.4828, Total Reward: -2.3490
# [DEBUG] Step Reward: 3.8241, Action Penalty: 0.2738, Total Reward: 3.5503
# [DEBUG] Step Reward: -1.8971, Action Penalty: 0.3691, Total Reward: -2.2662
# [DEBUG] Step Reward: 5.6412, Action Penalty: 0.3340, Total Reward: 5.3072
# [DEBUG] Step Reward: 2.8730, Action Penalty: 0.3927, Total Reward: 2.4803
# [DEBUG] Step Reward: 1.3157, Action Penalty: 0.3845, Total Reward: 0.9312
# [DEBUG] Step Reward: 3.6211, Action Penalty: 0.3026, Total Reward: 3.3186
# [DEBUG] Step Reward: 3.0352, Action Penalty: 0.3983, Total Reward: 2.6369
# [DEBUG] Step Reward: 0.5863, Action Penalty: 0.2769, Total Reward: 0.3094
# [DEBUG] Step Reward: 3.9306, Action Penalty: 0.4660, Total Reward: 3.4646
# [DEBUG] Step Reward: -2.2029, Action Penalty: 0.3817, Total Reward: -2.5846
# [DEBUG] Step Reward: 4.5120, Action Penalty: 0.3450, Total Reward: 4.1670
# [DEBUG] Step Reward: -0.6939, Action Penalty: 0.4730, Total Reward: -1.1669
# [DEBUG] Step Reward: 0.3518, Action Penalty: 0.3138, Total Reward: 0.0380
# [DEBUG] Step Reward: -2.9645, Action Penalty: 0.2521, Total Reward: -3.2166
# [DEBUG] Step Reward: -0.5799, Action Penalty: 0.3514, Total Reward: -0.9313
# [DEBUG] Step Reward: 0.0028, Action Penalty: 0.2228, Total Reward: -0.2200
# [DEBUG] Step Reward: 1.2263, Action Penalty: 0.3500, Total Reward: 0.8763
# [DEBUG] Step Reward: 5.0915, Action Penalty: 0.3591, Total Reward: 4.7324
# [DEBUG] Step Reward: 3.1290, Action Penalty: 0.4034, Total Reward: 2.7256
# [DEBUG] Step Reward: -0.3931, Action Penalty: 0.4014, Total Reward: -0.7945
# [DEBUG] Step Reward: 0.8382, Action Penalty: 0.2955, Total Reward: 0.5428
# [DEBUG] Step Reward: 1.7307, Action Penalty: 0.2471, Total Reward: 1.4837
# [DEBUG] Step Reward: 0.6666, Action Penalty: 0.3660, Total Reward: 0.3005
# [DEBUG] Step Reward: 1.2348, Action Penalty: 0.4885, Total Reward: 0.7462
# [DEBUG] Step Reward: 4.1407, Action Penalty: 0.3722, Total Reward: 3.7685
# [DEBUG] Step Reward: 2.9529, Action Penalty: 0.4452, Total Reward: 2.5077
# [DEBUG] Step Reward: -11.5121, Action Penalty: 0.2054, Total Reward: -11.7175
# [DEBUG] Step Reward: 0.1720, Action Penalty: 0.3924, Total Reward: -0.2204
# [DEBUG] Step Reward: -10.6313, Action Penalty: 0.4391, Total Reward: -11.0704
# [DEBUG] Step Reward: 5.9702, Action Penalty: 0.3415, Total Reward: 5.6287
# [DEBUG] Step Reward: -6.4953, Action Penalty: 0.2635, Total Reward: -6.7588
# [DEBUG] Step Reward: 0.0888, Action Penalty: 0.2767, Total Reward: -0.1879
# [DEBUG] Step Reward: 5.0232, Action Penalty: 0.2858, Total Reward: 4.7374
# [DEBUG] Step Reward: -2.0276, Action Penalty: 0.2734, Total Reward: -2.3010
# [DEBUG] Step Reward: -1.5124, Action Penalty: 0.3587, Total Reward: -1.8710
# [DEBUG] Step Reward: -3.0112, Action Penalty: 0.1807, Total Reward: -3.1918
# [DEBUG] Step Reward: -2.4830, Action Penalty: 0.2688, Total Reward: -2.7518
# [DEBUG] Step Reward: -3.2159, Action Penalty: 0.3519, Total Reward: -3.5677
# [DEBUG] Step Reward: -0.1993, Action Penalty: 0.4878, Total Reward: -0.6871
# [DEBUG] Step Reward: -6.6851, Action Penalty: 0.4558, Total Reward: -7.1409
# [DEBUG] Step Reward: 2.6295, Action Penalty: 0.2473, Total Reward: 2.3822
# [DEBUG] Step Reward: 5.8581, Action Penalty: 0.3679, Total Reward: 5.4902
# [DEBUG] Step Reward: 5.4630, Action Penalty: 0.3760, Total Reward: 5.0870
# [DEBUG] Step Reward: -1.5060, Action Penalty: 0.2635, Total Reward: -1.7695
# [DEBUG] Step Reward: 4.9528, Action Penalty: 0.2472, Total Reward: 4.7056
# [DEBUG] Step Reward: 0.3062, Action Penalty: 0.4114, Total Reward: -0.1052
# [DEBUG] Step Reward: -2.6990, Action Penalty: 0.4053, Total Reward: -3.1043
# [DEBUG] Step Reward: 6.3382, Action Penalty: 0.3423, Total Reward: 5.9959
# [DEBUG] Step Reward: -4.6565, Action Penalty: 0.2464, Total Reward: -4.9029
# [DEBUG] Step Reward: 5.7737, Action Penalty: 0.4773, Total Reward: 5.2964
# [DEBUG] Step Reward: 3.3918, Action Penalty: 0.4750, Total Reward: 2.9168
# [DEBUG] Step Reward: 2.3112, Action Penalty: 0.3600, Total Reward: 1.9512
# [DEBUG] Step Reward: 8.3968, Action Penalty: 0.3911, Total Reward: 8.0057
# [DEBUG] Step Reward: -4.6501, Action Penalty: 0.3788, Total Reward: -5.0289
# [DEBUG] Step Reward: -1.7199, Action Penalty: 0.2817, Total Reward: -2.0017
# [DEBUG] Step Reward: 0.0229, Action Penalty: 0.2384, Total Reward: -0.2155
# [DEBUG] Step Reward: 0.2153, Action Penalty: 0.2504, Total Reward: -0.0350
# [DEBUG] Step Reward: -5.1987, Action Penalty: 0.3182, Total Reward: -5.5169
# [DEBUG] Step Reward: 0.3661, Action Penalty: 0.4370, Total Reward: -0.0710
# [DEBUG] Step Reward: -2.7257, Action Penalty: 0.3604, Total Reward: -3.0862
# [DEBUG] Step Reward: 2.4810, Action Penalty: 0.3849, Total Reward: 2.0961
# [DEBUG] Step Reward: -1.4057, Action Penalty: 0.4846, Total Reward: -1.8902
# [DEBUG] Step Reward: -5.4618, Action Penalty: 0.4056, Total Reward: -5.8674
# [DEBUG] Step Reward: -2.5487, Action Penalty: 0.4796, Total Reward: -3.0283
# [DEBUG] Step Reward: -11.6840, Action Penalty: 0.3280, Total Reward: -12.0120
# [DEBUG] Step Reward: 2.9223, Action Penalty: 0.2539, Total Reward: 2.6684
# [DEBUG] Step Reward: -3.6256, Action Penalty: 0.2726, Total Reward: -3.8982
# [DEBUG] Step Reward: 3.8263, Action Penalty: 0.2904, Total Reward: 3.5359
# [DEBUG] Step Reward: 6.5942, Action Penalty: 0.3139, Total Reward: 6.2803
# [DEBUG] Step Reward: 6.9744, Action Penalty: 0.3947, Total Reward: 6.5797
# [DEBUG] Step Reward: 7.1803, Action Penalty: 0.3069, Total Reward: 6.8735
# [DEBUG] Step Reward: -2.2048, Action Penalty: 0.3052, Total Reward: -2.5101
# [DEBUG] Step Reward: 10.9153, Action Penalty: 0.2729, Total Reward: 10.6424
# [DEBUG] Step Reward: 1.5004, Action Penalty: 0.3046, Total Reward: 1.1957
# [DEBUG] Step Reward: 0.9181, Action Penalty: 0.2249, Total Reward: 0.6932
# [DEBUG] Step Reward: -1.6130, Action Penalty: 0.2628, Total Reward: -1.8758
# [DEBUG] Step Reward: 2.9723, Action Penalty: 0.2742, Total Reward: 2.6981
# [DEBUG] Step Reward: 3.9271, Action Penalty: 0.2874, Total Reward: 3.6397
# [DEBUG] Step Reward: -2.5356, Action Penalty: 0.4481, Total Reward: -2.9837
# [DEBUG] Step Reward: -3.6218, Action Penalty: 0.3190, Total Reward: -3.9408
# [DEBUG] Step Reward: -0.5431, Action Penalty: 0.3860, Total Reward: -0.9291
# [DEBUG] Step Reward: -2.5323, Action Penalty: 0.3793, Total Reward: -2.9116
# [DEBUG] Step Reward: 0.6783, Action Penalty: 0.5732, Total Reward: 0.1051
# [DEBUG] Step Reward: 6.2869, Action Penalty: 0.4315, Total Reward: 5.8554
# [DEBUG] Step Reward: -0.9351, Action Penalty: 0.4343, Total Reward: -1.3694
# [DEBUG] Step Reward: 1.0926, Action Penalty: 0.3667, Total Reward: 0.7259
# [DEBUG] Step Reward: -0.6254, Action Penalty: 0.3593, Total Reward: -0.9847
# [DEBUG] Step Reward: 5.7160, Action Penalty: 0.2145, Total Reward: 5.5014
# [DEBUG] Step Reward: 3.9171, Action Penalty: 0.4210, Total Reward: 3.4961
# [DEBUG] Step Reward: -0.0024, Action Penalty: 0.3396, Total Reward: -0.3420
# [DEBUG] Step Reward: 3.4007, Action Penalty: 0.3656, Total Reward: 3.0351
# [DEBUG] Step Reward: -1.3813, Action Penalty: 0.2164, Total Reward: -1.5978
# [DEBUG] Step Reward: 1.3998, Action Penalty: 0.3152, Total Reward: 1.0846
# [DEBUG] Step Reward: -1.9627, Action Penalty: 0.2972, Total Reward: -2.2599
# [DEBUG] Step Reward: -0.3318, Action Penalty: 0.4272, Total Reward: -0.7590
# [DEBUG] Step Reward: -2.3729, Action Penalty: 0.3702, Total Reward: -2.7431
# [DEBUG] Step Reward: -2.7081, Action Penalty: 0.2379, Total Reward: -2.9461
# [DEBUG] Step Reward: 8.1132, Action Penalty: 0.1534, Total Reward: 7.9598
# [DEBUG] Step Reward: -0.1654, Action Penalty: 0.3081, Total Reward: -0.4735
# [DEBUG] Step Reward: 1.5590, Action Penalty: 0.3451, Total Reward: 1.2140
# [DEBUG] Step Reward: -3.3489, Action Penalty: 0.3309, Total Reward: -3.6798
# [DEBUG] Step Reward: 3.6528, Action Penalty: 0.3531, Total Reward: 3.2998
# [DEBUG] Step Reward: -0.1009, Action Penalty: 0.4325, Total Reward: -0.5334
# [DEBUG] Step Reward: 2.5667, Action Penalty: 0.3993, Total Reward: 2.1674
# [DEBUG] Step Reward: 1.6620, Action Penalty: 0.3846, Total Reward: 1.2774
# [DEBUG] Step Reward: 5.4991, Action Penalty: 0.3549, Total Reward: 5.1442
# [DEBUG] Step Reward: -1.0220, Action Penalty: 0.3536, Total Reward: -1.3756
# [DEBUG] Step Reward: -0.0422, Action Penalty: 0.4220, Total Reward: -0.4641
# [DEBUG] Step Reward: 2.9009, Action Penalty: 0.2579, Total Reward: 2.6430
# [DEBUG] Step Reward: -3.6854, Action Penalty: 0.2764, Total Reward: -3.9619
# [DEBUG] Step Reward: 2.8785, Action Penalty: 0.2475, Total Reward: 2.6310
# [DEBUG] Step Reward: 6.7672, Action Penalty: 0.3242, Total Reward: 6.4430
# [DEBUG] Step Reward: 7.1858, Action Penalty: 0.3295, Total Reward: 6.8564
# [DEBUG] Step Reward: 0.0394, Action Penalty: 0.2675, Total Reward: -0.2281
# [DEBUG] Step Reward: -1.7551, Action Penalty: 0.3343, Total Reward: -2.0894
# [DEBUG] Step Reward: 2.3230, Action Penalty: 0.3618, Total Reward: 1.9613
# [DEBUG] Step Reward: 1.9001, Action Penalty: 0.4332, Total Reward: 1.4670
# [DEBUG] Step Reward: 0.7612, Action Penalty: 0.3875, Total Reward: 0.3737
# [DEBUG] Step Reward: -4.4802, Action Penalty: 0.3010, Total Reward: -4.7812
# [DEBUG] Step Reward: 0.6213, Action Penalty: 0.2826, Total Reward: 0.3387
# [DEBUG] Step Reward: 1.8621, Action Penalty: 0.3005, Total Reward: 1.5616
# [DEBUG] Step Reward: 4.7836, Action Penalty: 0.3514, Total Reward: 4.4321
# [DEBUG] Step Reward: -3.4451, Action Penalty: 0.4363, Total Reward: -3.8814
# [DEBUG] Step Reward: 0.2064, Action Penalty: 0.4426, Total Reward: -0.2363
# [DEBUG] Step Reward: -0.2904, Action Penalty: 0.2512, Total Reward: -0.5415
# [DEBUG] Step Reward: -7.6603, Action Penalty: 0.3226, Total Reward: -7.9829
# [DEBUG] Step Reward: 0.0591, Action Penalty: 0.4371, Total Reward: -0.3780
# [DEBUG] Step Reward: -7.9933, Action Penalty: 0.2604, Total Reward: -8.2537
# [DEBUG] Step Reward: 3.4721, Action Penalty: 0.3086, Total Reward: 3.1635
# [DEBUG] Step Reward: 6.4674, Action Penalty: 0.4015, Total Reward: 6.0658
# [DEBUG] Step Reward: -0.5889, Action Penalty: 0.3987, Total Reward: -0.9875
# [DEBUG] Step Reward: 4.5881, Action Penalty: 0.3194, Total Reward: 4.2687
# [DEBUG] Step Reward: -0.5326, Action Penalty: 0.2325, Total Reward: -0.7651
# [DEBUG] Step Reward: 3.4382, Action Penalty: 0.1587, Total Reward: 3.2795
# [DEBUG] Step Reward: 0.1752, Action Penalty: 0.1791, Total Reward: -0.0039
# [DEBUG] Step Reward: 1.3496, Action Penalty: 0.1993, Total Reward: 1.1503
# [DEBUG] Step Reward: -0.4496, Action Penalty: 0.1736, Total Reward: -0.6232
# [DEBUG] Step Reward: 1.2034, Action Penalty: 0.1937, Total Reward: 1.0098
# [DEBUG] Step Reward: 0.3904, Action Penalty: 0.2633, Total Reward: 0.1271
# [DEBUG] Step Reward: -1.3092, Action Penalty: 0.2750, Total Reward: -1.5842
# [DEBUG] Step Reward: -1.1643, Action Penalty: 0.5176, Total Reward: -1.6819
# [DEBUG] Step Reward: 2.4889, Action Penalty: 0.4055, Total Reward: 2.0834
# [DEBUG] Step Reward: -0.5304, Action Penalty: 0.3895, Total Reward: -0.9200
# [DEBUG] Step Reward: 1.2277, Action Penalty: 0.4644, Total Reward: 0.7633
# [DEBUG] Step Reward: 5.2045, Action Penalty: 0.2807, Total Reward: 4.9238
# [DEBUG] Step Reward: -6.4949, Action Penalty: 0.3565, Total Reward: -6.8513
# [DEBUG] Step Reward: -4.4968, Action Penalty: 0.4188, Total Reward: -4.9157
# [DEBUG] Step Reward: 10.5569, Action Penalty: 0.3549, Total Reward: 10.2020
# [DEBUG] Step Reward: -3.0745, Action Penalty: 0.1912, Total Reward: -3.2656
# [DEBUG] Step Reward: -1.4684, Action Penalty: 0.2674, Total Reward: -1.7358
# [DEBUG] Step Reward: -4.7574, Action Penalty: 0.2506, Total Reward: -5.0080
# [DEBUG] Step Reward: 6.5480, Action Penalty: 0.4301, Total Reward: 6.1178
# [DEBUG] Step Reward: -0.4553, Action Penalty: 0.3962, Total Reward: -0.8516
# [DEBUG] Step Reward: 2.4328, Action Penalty: 0.2845, Total Reward: 2.1483
# [DEBUG] Step Reward: 3.4225, Action Penalty: 0.3482, Total Reward: 3.0744
# [DEBUG] Step Reward: 2.0058, Action Penalty: 0.4021, Total Reward: 1.6037
# [DEBUG] Step Reward: 3.2314, Action Penalty: 0.3094, Total Reward: 2.9219
# [DEBUG] Step Reward: 1.6780, Action Penalty: 0.3183, Total Reward: 1.3597
# [DEBUG] Step Reward: -0.6344, Action Penalty: 0.4557, Total Reward: -1.0901
# [DEBUG] Step Reward: 1.4308, Action Penalty: 0.3000, Total Reward: 1.1308
# [DEBUG] Step Reward: -1.0645, Action Penalty: 0.2939, Total Reward: -1.3584
# [DEBUG] Step Reward: -2.4411, Action Penalty: 0.3041, Total Reward: -2.7452
# [DEBUG] Step Reward: 1.4068, Action Penalty: 0.2854, Total Reward: 1.1214
# [DEBUG] Step Reward: -4.3460, Action Penalty: 0.2657, Total Reward: -4.6118
# [DEBUG] Step Reward: -1.0422, Action Penalty: 0.3717, Total Reward: -1.4139
# [DEBUG] Step Reward: 2.6617, Action Penalty: 0.4417, Total Reward: 2.2200
# [DEBUG] Step Reward: 4.6273, Action Penalty: 0.4413, Total Reward: 4.1860
# [DEBUG] Step Reward: -0.4908, Action Penalty: 0.3476, Total Reward: -0.8383
# [DEBUG] Step Reward: -0.5047, Action Penalty: 0.2855, Total Reward: -0.7902
# [DEBUG] Step Reward: -0.9055, Action Penalty: 0.2324, Total Reward: -1.1379
# [DEBUG] Step Reward: 0.6953, Action Penalty: 0.4355, Total Reward: 0.2598
# [DEBUG] Step Reward: 3.7246, Action Penalty: 0.5051, Total Reward: 3.2196
# [DEBUG] Step Reward: -1.5050, Action Penalty: 0.3501, Total Reward: -1.8552
# [DEBUG] Step Reward: 2.6613, Action Penalty: 0.4125, Total Reward: 2.2488
# [DEBUG] Step Reward: 2.7190, Action Penalty: 0.4018, Total Reward: 2.3172
# [DEBUG] Step Reward: 4.6730, Action Penalty: 0.2851, Total Reward: 4.3879
# [DEBUG] Step Reward: -2.1884, Action Penalty: 0.3079, Total Reward: -2.4962
# [DEBUG] Step Reward: -0.7299, Action Penalty: 0.3687, Total Reward: -1.0986
# [DEBUG] Step Reward: -0.6173, Action Penalty: 0.2727, Total Reward: -0.8899
# [DEBUG] Step Reward: 5.9242, Action Penalty: 0.4031, Total Reward: 5.5211
# [DEBUG] Step Reward: 1.7440, Action Penalty: 0.3719, Total Reward: 1.3721
# [DEBUG] Step Reward: -0.4158, Action Penalty: 0.3939, Total Reward: -0.8097
# [DEBUG] Step Reward: -3.0410, Action Penalty: 0.3991, Total Reward: -3.4401
# [DEBUG] Step Reward: 3.7292, Action Penalty: 0.4162, Total Reward: 3.3130
# [DEBUG] Step Reward: -4.9193, Action Penalty: 0.2721, Total Reward: -5.1914
# [DEBUG] Step Reward: 4.1262, Action Penalty: 0.4219, Total Reward: 3.7043
# [DEBUG] Step Reward: 0.5905, Action Penalty: 0.4220, Total Reward: 0.1685
# [DEBUG] Step Reward: -0.1600, Action Penalty: 0.3525, Total Reward: -0.5125
# [DEBUG] Step Reward: 0.3325, Action Penalty: 0.4217, Total Reward: -0.0892
# [DEBUG] Step Reward: 3.6398, Action Penalty: 0.2462, Total Reward: 3.3936
# [DEBUG] Step Reward: -4.3528, Action Penalty: 0.2523, Total Reward: -4.6051
# [DEBUG] Step Reward: 3.1598, Action Penalty: 0.2816, Total Reward: 2.8782
# [DEBUG] Step Reward: -0.8230, Action Penalty: 0.2576, Total Reward: -1.0807
# [DEBUG] Step Reward: 2.9488, Action Penalty: 0.4355, Total Reward: 2.5134
# [DEBUG] Step Reward: 5.1257, Action Penalty: 0.3712, Total Reward: 4.7544
# [DEBUG] Step Reward: 2.8620, Action Penalty: 0.3788, Total Reward: 2.4832
# [DEBUG] Step Reward: -2.2610, Action Penalty: 0.3461, Total Reward: -2.6071
# [DEBUG] Step Reward: -6.6447, Action Penalty: 0.3719, Total Reward: -7.0166
# [DEBUG] Step Reward: -6.4982, Action Penalty: 0.1929, Total Reward: -6.6911
# [DEBUG] Step Reward: 5.8909, Action Penalty: 0.3661, Total Reward: 5.5248
# [DEBUG] Step Reward: 6.0373, Action Penalty: 0.5121, Total Reward: 5.5253
# [DEBUG] Step Reward: -0.5264, Action Penalty: 0.3474, Total Reward: -0.8737
# [DEBUG] Step Reward: -3.5460, Action Penalty: 0.3320, Total Reward: -3.8781
# [DEBUG] Step Reward: -2.0023, Action Penalty: 0.3897, Total Reward: -2.3920
# [DEBUG] Step Reward: 2.3930, Action Penalty: 0.2422, Total Reward: 2.1508
# [DEBUG] Step Reward: 1.4708, Action Penalty: 0.4318, Total Reward: 1.0390
# [DEBUG] Step Reward: 2.7294, Action Penalty: 0.3240, Total Reward: 2.4054
# [DEBUG] Step Reward: -1.5634, Action Penalty: 0.3954, Total Reward: -1.9588
# [DEBUG] Step Reward: 0.4182, Action Penalty: 0.4560, Total Reward: -0.0379
# [DEBUG] Step Reward: 1.0148, Action Penalty: 0.3153, Total Reward: 0.6995
# [DEBUG] Step Reward: -0.1217, Action Penalty: 0.4040, Total Reward: -0.5257
# [DEBUG] Step Reward: 1.0485, Action Penalty: 0.2933, Total Reward: 0.7552
# [DEBUG] Step Reward: 1.2411, Action Penalty: 0.4225, Total Reward: 0.8186
# [DEBUG] Step Reward: -0.1889, Action Penalty: 0.2319, Total Reward: -0.4209
# [DEBUG] Step Reward: 2.7599, Action Penalty: 0.3349, Total Reward: 2.4250
# [DEBUG] Step Reward: -2.4611, Action Penalty: 0.4777, Total Reward: -2.9388
# [DEBUG] Step Reward: -0.0713, Action Penalty: 0.2796, Total Reward: -0.3509
# [DEBUG] Step Reward: -1.0969, Action Penalty: 0.3137, Total Reward: -1.4106
# [DEBUG] Step Reward: -3.8534, Action Penalty: 0.4879, Total Reward: -4.3413
# [DEBUG] Step Reward: 0.5131, Action Penalty: 0.3063, Total Reward: 0.2068
# [DEBUG] Step Reward: 0.6268, Action Penalty: 0.3645, Total Reward: 0.2623
# [DEBUG] Step Reward: -1.6280, Action Penalty: 0.3629, Total Reward: -1.9909
# [DEBUG] Step Reward: -0.8092, Action Penalty: 0.3416, Total Reward: -1.1508
# [DEBUG] Step Reward: -3.2376, Action Penalty: 0.3509, Total Reward: -3.5885
# [DEBUG] Step Reward: -7.9881, Action Penalty: 0.3817, Total Reward: -8.3697
# [DEBUG] Step Reward: 7.7290, Action Penalty: 0.4285, Total Reward: 7.3005
# [DEBUG] Step Reward: 1.1163, Action Penalty: 0.4124, Total Reward: 0.7040
# [DEBUG] Step Reward: -0.3023, Action Penalty: 0.4230, Total Reward: -0.7253
# [DEBUG] Step Reward: 3.7214, Action Penalty: 0.3129, Total Reward: 3.4085
# [DEBUG] Step Reward: 1.5541, Action Penalty: 0.3531, Total Reward: 1.2011
# [DEBUG] Step Reward: 0.4511, Action Penalty: 0.2848, Total Reward: 0.1664
# [DEBUG] Step Reward: 0.8012, Action Penalty: 0.2251, Total Reward: 0.5760
# [DEBUG] Step Reward: 3.0841, Action Penalty: 0.2651, Total Reward: 2.8190
# [DEBUG] Step Reward: 1.2119, Action Penalty: 0.4402, Total Reward: 0.7718
# [DEBUG] Step Reward: 2.9852, Action Penalty: 0.3415, Total Reward: 2.6437
# [DEBUG] Step Reward: -0.8602, Action Penalty: 0.3420, Total Reward: -1.2022
# [DEBUG] Step Reward: 2.5067, Action Penalty: 0.2164, Total Reward: 2.2903
# [DEBUG] Step Reward: -4.7043, Action Penalty: 0.1538, Total Reward: -4.8581
# [DEBUG] Step Reward: 7.3295, Action Penalty: 0.3376, Total Reward: 6.9919
# [DEBUG] Step Reward: 3.0043, Action Penalty: 0.4657, Total Reward: 2.5386
# [DEBUG] Step Reward: -0.8428, Action Penalty: 0.2882, Total Reward: -1.1310
# [DEBUG] Step Reward: 1.1050, Action Penalty: 0.2131, Total Reward: 0.8919
# [DEBUG] Step Reward: -0.2797, Action Penalty: 0.3821, Total Reward: -0.6619
# [DEBUG] Step Reward: -5.6480, Action Penalty: 0.3925, Total Reward: -6.0405
# [DEBUG] Step Reward: -10.2774, Action Penalty: 0.3270, Total Reward: -10.6044
# [DEBUG] Step Reward: 8.3942, Action Penalty: 0.2310, Total Reward: 8.1632
# [DEBUG] Step Reward: 3.9542, Action Penalty: 0.3285, Total Reward: 3.6257
# [DEBUG] Step Reward: 0.1668, Action Penalty: 0.3951, Total Reward: -0.2283
# [DEBUG] Step Reward: 1.6755, Action Penalty: 0.3870, Total Reward: 1.2885
# [DEBUG] Step Reward: 0.9355, Action Penalty: 0.2738, Total Reward: 0.6617
# [DEBUG] Step Reward: -1.9908, Action Penalty: 0.2860, Total Reward: -2.2768
# [DEBUG] Step Reward: -2.9590, Action Penalty: 0.3105, Total Reward: -3.2695
# [DEBUG] Step Reward: 2.6804, Action Penalty: 0.2413, Total Reward: 2.4390
# [DEBUG] Step Reward: -1.6836, Action Penalty: 0.3046, Total Reward: -1.9882
# [DEBUG] Step Reward: 0.4734, Action Penalty: 0.3130, Total Reward: 0.1605
# [DEBUG] Step Reward: 4.8290, Action Penalty: 0.3823, Total Reward: 4.4468
# [DEBUG] Step Reward: -2.3354, Action Penalty: 0.4185, Total Reward: -2.7539
# [DEBUG] Step Reward: 0.7888, Action Penalty: 0.3294, Total Reward: 0.4594
# [DEBUG] Step Reward: 4.5713, Action Penalty: 0.3452, Total Reward: 4.2261
# [DEBUG] Step Reward: -0.5766, Action Penalty: 0.3874, Total Reward: -0.9639
# [DEBUG] Step Reward: 2.1752, Action Penalty: 0.3240, Total Reward: 1.8512
# [DEBUG] Step Reward: 2.2675, Action Penalty: 0.2867, Total Reward: 1.9808
# [DEBUG] Step Reward: 2.3325, Action Penalty: 0.1744, Total Reward: 2.1581
# [DEBUG] Step Reward: -0.7092, Action Penalty: 0.3377, Total Reward: -1.0468
# [DEBUG] Step Reward: 2.3346, Action Penalty: 0.5196, Total Reward: 1.8150
# [DEBUG] Step Reward: -1.8164, Action Penalty: 0.4244, Total Reward: -2.2408
# [DEBUG] Step Reward: -7.0087, Action Penalty: 0.2380, Total Reward: -7.2467
# [DEBUG] Step Reward: 0.0961, Action Penalty: 0.2436, Total Reward: -0.1475
# [DEBUG] Step Reward: 2.4514, Action Penalty: 0.3578, Total Reward: 2.0936
# [DEBUG] Step Reward: 2.9493, Action Penalty: 0.3274, Total Reward: 2.6218
# [DEBUG] Step Reward: 1.3444, Action Penalty: 0.2084, Total Reward: 1.1360
# [DEBUG] Step Reward: 0.9453, Action Penalty: 0.3094, Total Reward: 0.6359
# [DEBUG] Step Reward: -1.8669, Action Penalty: 0.3313, Total Reward: -2.1983
# [DEBUG] Step Reward: 3.7062, Action Penalty: 0.4022, Total Reward: 3.3040
# [DEBUG] Step Reward: 0.6812, Action Penalty: 0.4698, Total Reward: 0.2115
# [DEBUG] Step Reward: -0.8849, Action Penalty: 0.4615, Total Reward: -1.3464
# [DEBUG] Step Reward: 0.0941, Action Penalty: 0.4446, Total Reward: -0.3505
# [DEBUG] Step Reward: 2.8388, Action Penalty: 0.3715, Total Reward: 2.4673
# [DEBUG] Step Reward: -1.1136, Action Penalty: 0.2801, Total Reward: -1.3936
# [DEBUG] Step Reward: 0.2026, Action Penalty: 0.2212, Total Reward: -0.0186
# [DEBUG] Step Reward: -3.8306, Action Penalty: 0.1667, Total Reward: -3.9973
# [DEBUG] Step Reward: -1.9479, Action Penalty: 0.2379, Total Reward: -2.1858
# [DEBUG] Step Reward: -6.7968, Action Penalty: 0.2228, Total Reward: -7.0196
# [DEBUG] Step Reward: 5.0122, Action Penalty: 0.1778, Total Reward: 4.8343
# [DEBUG] Step Reward: -4.7177, Action Penalty: 0.2428, Total Reward: -4.9606
# [DEBUG] Step Reward: 2.7833, Action Penalty: 0.3962, Total Reward: 2.3871
# [DEBUG] Step Reward: -1.5002, Action Penalty: 0.3256, Total Reward: -1.8258
# [DEBUG] Step Reward: -3.2152, Action Penalty: 0.4383, Total Reward: -3.6535
# [DEBUG] Step Reward: -9.9517, Action Penalty: 0.4779, Total Reward: -10.4296
# [DEBUG] Step Reward: 0.0471, Action Penalty: 0.4441, Total Reward: -0.3970
# [DEBUG] Step Reward: 4.9219, Action Penalty: 0.4247, Total Reward: 4.4972
# [DEBUG] Step Reward: 6.0179, Action Penalty: 0.4159, Total Reward: 5.6019
# [DEBUG] Step Reward: 0.9101, Action Penalty: 0.2861, Total Reward: 0.6240
# [DEBUG] Step Reward: 1.8327, Action Penalty: 0.3444, Total Reward: 1.4883
# [DEBUG] Step Reward: -7.0693, Action Penalty: 0.3632, Total Reward: -7.4325
# [DEBUG] Step Reward: -0.0282, Action Penalty: 0.5703, Total Reward: -0.5985
# [DEBUG] Step Reward: -6.6070, Action Penalty: 0.5113, Total Reward: -7.1183
# [DEBUG] Step Reward: 4.4662, Action Penalty: 0.3167, Total Reward: 4.1495
# [DEBUG] Step Reward: -5.4558, Action Penalty: 0.3383, Total Reward: -5.7941
# [DEBUG] Step Reward: 6.0639, Action Penalty: 0.2884, Total Reward: 5.7755
# [DEBUG] Step Reward: 1.1731, Action Penalty: 0.2174, Total Reward: 0.9558
# [DEBUG] Step Reward: 4.6167, Action Penalty: 0.2541, Total Reward: 4.3626
# [DEBUG] Step Reward: 0.8215, Action Penalty: 0.3139, Total Reward: 0.5077
# [DEBUG] Step Reward: -4.1620, Action Penalty: 0.3801, Total Reward: -4.5422
# [DEBUG] Step Reward: -2.7831, Action Penalty: 0.3428, Total Reward: -3.1259
# [DEBUG] Step Reward: -2.2918, Action Penalty: 0.3497, Total Reward: -2.6416
# [DEBUG] Step Reward: 9.2009, Action Penalty: 0.3909, Total Reward: 8.8100
# [DEBUG] Step Reward: 7.7419, Action Penalty: 0.3184, Total Reward: 7.4235
# [DEBUG] Step Reward: 1.4564, Action Penalty: 0.3124, Total Reward: 1.1440
# [DEBUG] Step Reward: 3.4482, Action Penalty: 0.3222, Total Reward: 3.1260
# [DEBUG] Step Reward: 2.9970, Action Penalty: 0.3944, Total Reward: 2.6027
# [DEBUG] Step Reward: -1.3032, Action Penalty: 0.3505, Total Reward: -1.6538
# [DEBUG] Step Reward: 1.8367, Action Penalty: 0.3225, Total Reward: 1.5142
# [DEBUG] Step Reward: -0.5767, Action Penalty: 0.3679, Total Reward: -0.9446
# [DEBUG] Step Reward: 1.6889, Action Penalty: 0.3806, Total Reward: 1.3083
# [DEBUG] Step Reward: -4.6054, Action Penalty: 0.3516, Total Reward: -4.9569
# [DEBUG] Step Reward: 5.1439, Action Penalty: 0.3368, Total Reward: 4.8071
# [DEBUG] Step Reward: -1.4526, Action Penalty: 0.4238, Total Reward: -1.8764
# [DEBUG] Step Reward: -0.6001, Action Penalty: 0.1927, Total Reward: -0.7928
# [DEBUG] Step Reward: 2.6294, Action Penalty: 0.2674, Total Reward: 2.3621
# [DEBUG] Step Reward: 0.7991, Action Penalty: 0.3386, Total Reward: 0.4605
# [DEBUG] Step Reward: -3.0984, Action Penalty: 0.4846, Total Reward: -3.5830
# [DEBUG] Step Reward: 1.0795, Action Penalty: 0.3230, Total Reward: 0.7566
# [DEBUG] Step Reward: 2.7902, Action Penalty: 0.1831, Total Reward: 2.6071
# [DEBUG] Step Reward: -1.3675, Action Penalty: 0.2542, Total Reward: -1.6217
# [DEBUG] Step Reward: -4.4004, Action Penalty: 0.2099, Total Reward: -4.6102
# [DEBUG] Step Reward: -0.0080, Action Penalty: 0.1570, Total Reward: -0.1650
# [DEBUG] Step Reward: 2.5048, Action Penalty: 0.2430, Total Reward: 2.2617
# [DEBUG] Step Reward: -2.0093, Action Penalty: 0.3630, Total Reward: -2.3722
# [DEBUG] Step Reward: -0.8378, Action Penalty: 0.3716, Total Reward: -1.2094
# [DEBUG] Step Reward: -1.1109, Action Penalty: 0.3784, Total Reward: -1.4893
# [DEBUG] Step Reward: 1.5514, Action Penalty: 0.4248, Total Reward: 1.1266
# [DEBUG] Step Reward: -1.7605, Action Penalty: 0.3273, Total Reward: -2.0878
# [DEBUG] Step Reward: 2.1200, Action Penalty: 0.5464, Total Reward: 1.5736
# [DEBUG] Step Reward: 5.4862, Action Penalty: 0.4956, Total Reward: 4.9906
# [DEBUG] Step Reward: -0.4730, Action Penalty: 0.2788, Total Reward: -0.7518
# [DEBUG] Step Reward: -12.8983, Action Penalty: 0.2466, Total Reward: -13.1449
# [DEBUG] Step Reward: 5.1734, Action Penalty: 0.2621, Total Reward: 4.9113
# [DEBUG] Step Reward: -2.1270, Action Penalty: 0.2658, Total Reward: -2.3927
# [DEBUG] Step Reward: -2.2165, Action Penalty: 0.2807, Total Reward: -2.4972
# [DEBUG] Step Reward: 4.4732, Action Penalty: 0.3845, Total Reward: 4.0886
# [DEBUG] Step Reward: -1.7870, Action Penalty: 0.2873, Total Reward: -2.0743
# [DEBUG] Step Reward: 8.9857, Action Penalty: 0.3003, Total Reward: 8.6854
# [DEBUG] Step Reward: 10.2892, Action Penalty: 0.2274, Total Reward: 10.0618
# [DEBUG] Step Reward: 2.9353, Action Penalty: 0.3132, Total Reward: 2.6220
# [DEBUG] Step Reward: 0.0381, Action Penalty: 0.3436, Total Reward: -0.3055
# [DEBUG] Step Reward: 3.2595, Action Penalty: 0.3479, Total Reward: 2.9116
# [DEBUG] Step Reward: -5.1265, Action Penalty: 0.2418, Total Reward: -5.3683
# [DEBUG] Step Reward: 0.5976, Action Penalty: 0.3269, Total Reward: 0.2706
# [DEBUG] Step Reward: 6.8505, Action Penalty: 0.2762, Total Reward: 6.5743
# [DEBUG] Step Reward: -2.1361, Action Penalty: 0.4574, Total Reward: -2.5935
# [DEBUG] Step Reward: -7.8139, Action Penalty: 0.4890, Total Reward: -8.3028
# [DEBUG] Step Reward: -6.2908, Action Penalty: 0.3215, Total Reward: -6.6123
# [DEBUG] Step Reward: 7.0538, Action Penalty: 0.3151, Total Reward: 6.7387
# [DEBUG] Step Reward: 4.8049, Action Penalty: 0.4246, Total Reward: 4.3803
# [DEBUG] Step Reward: 2.3536, Action Penalty: 0.4413, Total Reward: 1.9124
# [DEBUG] Step Reward: 5.5190, Action Penalty: 0.3797, Total Reward: 5.1393
# [DEBUG] Step Reward: 0.1496, Action Penalty: 0.3859, Total Reward: -0.2363
# [DEBUG] Step Reward: 0.6303, Action Penalty: 0.2627, Total Reward: 0.3676
# [DEBUG] Step Reward: -1.0972, Action Penalty: 0.2556, Total Reward: -1.3528
# [DEBUG] Step Reward: -1.9306, Action Penalty: 0.3618, Total Reward: -2.2925
# [DEBUG] Step Reward: 8.5734, Action Penalty: 0.4527, Total Reward: 8.1208
# [DEBUG] Step Reward: 2.3053, Action Penalty: 0.3225, Total Reward: 1.9827
# [DEBUG] Step Reward: -6.5623, Action Penalty: 0.2624, Total Reward: -6.8247
# [DEBUG] Step Reward: -5.7152, Action Penalty: 0.1803, Total Reward: -5.8955
# [DEBUG] Step Reward: -0.5863, Action Penalty: 0.3296, Total Reward: -0.9158
# [DEBUG] Step Reward: 1.6722, Action Penalty: 0.2630, Total Reward: 1.4091
# [DEBUG] Step Reward: 3.3789, Action Penalty: 0.3720, Total Reward: 3.0069
# [DEBUG] Step Reward: -0.8618, Action Penalty: 0.2971, Total Reward: -1.1589
# [DEBUG] Step Reward: -3.9281, Action Penalty: 0.2686, Total Reward: -4.1967
# [DEBUG] Step Reward: -4.9660, Action Penalty: 0.3958, Total Reward: -5.3618
# [DEBUG] Step Reward: -12.0563, Action Penalty: 0.4440, Total Reward: -12.5003
# [DEBUG] Step Reward: -6.5361, Action Penalty: 0.3600, Total Reward: -6.8961
# [DEBUG] Step Reward: -3.0689, Action Penalty: 0.3922, Total Reward: -3.4611
# [DEBUG] Step Reward: -4.5485, Action Penalty: 0.4149, Total Reward: -4.9634
# [DEBUG] Step Reward: -0.9081, Action Penalty: 0.3483, Total Reward: -1.2563
# [DEBUG] Step Reward: 1.3519, Action Penalty: 0.3048, Total Reward: 1.0471
# [DEBUG] Step Reward: 1.1754, Action Penalty: 0.3938, Total Reward: 0.7816
# [DEBUG] Step Reward: -2.5436, Action Penalty: 0.2862, Total Reward: -2.8298
# [DEBUG] Step Reward: 11.0978, Action Penalty: 0.3355, Total Reward: 10.7624
# [DEBUG] Step Reward: 7.6806, Action Penalty: 0.3736, Total Reward: 7.3069
# [DEBUG] Step Reward: 2.5796, Action Penalty: 0.3114, Total Reward: 2.2681
# [DEBUG] Step Reward: 3.1978, Action Penalty: 0.3481, Total Reward: 2.8497
# [DEBUG] Step Reward: -2.7876, Action Penalty: 0.2656, Total Reward: -3.0532
# [DEBUG] Step Reward: 1.5294, Action Penalty: 0.3026, Total Reward: 1.2268
# [DEBUG] Step Reward: 0.1209, Action Penalty: 0.2402, Total Reward: -0.1193
# [DEBUG] Step Reward: 6.8559, Action Penalty: 0.2652, Total Reward: 6.5908
# [DEBUG] Step Reward: 4.1453, Action Penalty: 0.3722, Total Reward: 3.7731
# [DEBUG] Step Reward: -7.7128, Action Penalty: 0.2244, Total Reward: -7.9372
# [DEBUG] Step Reward: -8.1350, Action Penalty: 0.2053, Total Reward: -8.3403
# [DEBUG] Step Reward: -2.4910, Action Penalty: 0.1894, Total Reward: -2.6804
# [DEBUG] Step Reward: 7.0554, Action Penalty: 0.2858, Total Reward: 6.7696
# [DEBUG] Step Reward: -0.6409, Action Penalty: 0.2818, Total Reward: -0.9227
# [DEBUG] Step Reward: -10.4317, Action Penalty: 0.4460, Total Reward: -10.8777
# [DEBUG] Step Reward: -3.7426, Action Penalty: 0.4597, Total Reward: -4.2024
# [DEBUG] Step Reward: -4.7786, Action Penalty: 0.3679, Total Reward: -5.1465
# [DEBUG] Step Reward: -6.7375, Action Penalty: 0.2963, Total Reward: -7.0337
# [DEBUG] Step Reward: -0.3014, Action Penalty: 0.2210, Total Reward: -0.5225
# [DEBUG] Step Reward: 11.8963, Action Penalty: 0.4013, Total Reward: 11.4950
# [DEBUG] Step Reward: -3.8903, Action Penalty: 0.4342, Total Reward: -4.3245
# [DEBUG] Step Reward: -8.8975, Action Penalty: 0.2777, Total Reward: -9.1752
# [DEBUG] Step Reward: 9.3750, Action Penalty: 0.2199, Total Reward: 9.1551
# [DEBUG] Step Reward: -0.3889, Action Penalty: 0.2129, Total Reward: -0.6018
# [DEBUG] Step Reward: -2.7950, Action Penalty: 0.2133, Total Reward: -3.0083
# [DEBUG] Step Reward: -10.2821, Action Penalty: 0.2504, Total Reward: -10.5326
# [DEBUG] Step Reward: -4.2325, Action Penalty: 0.3717, Total Reward: -4.6042
# [DEBUG] Step Reward: 12.3542, Action Penalty: 0.4113, Total Reward: 11.9430
# [DEBUG] Step Reward: -3.7647, Action Penalty: 0.3476, Total Reward: -4.1123
# [DEBUG] Step Reward: -6.2736, Action Penalty: 0.2904, Total Reward: -6.5640
# [DEBUG] Step Reward: -1.3255, Action Penalty: 0.3336, Total Reward: -1.6591
# [DEBUG] Step Reward: 8.8786, Action Penalty: 0.4244, Total Reward: 8.4542
# [DEBUG] Step Reward: 9.0200, Action Penalty: 0.4404, Total Reward: 8.5796
# [DEBUG] Step Reward: 5.8582, Action Penalty: 0.3030, Total Reward: 5.5552
# [DEBUG] Step Reward: 3.2178, Action Penalty: 0.4861, Total Reward: 2.7317
# [DEBUG] Step Reward: -0.0486, Action Penalty: 0.3774, Total Reward: -0.4260
# [DEBUG] Step Reward: 4.6003, Action Penalty: 0.3857, Total Reward: 4.2147
# [DEBUG] Step Reward: -3.0589, Action Penalty: 0.3006, Total Reward: -3.3595
# [DEBUG] Step Reward: 7.2980, Action Penalty: 0.4700, Total Reward: 6.8280
# [DEBUG] Step Reward: 2.0793, Action Penalty: 0.3803, Total Reward: 1.6990
# [DEBUG] Step Reward: -0.0463, Action Penalty: 0.3215, Total Reward: -0.3678
# [DEBUG] Step Reward: 3.6053, Action Penalty: 0.1716, Total Reward: 3.4338
# [DEBUG] Step Reward: -0.0478, Action Penalty: 0.2382, Total Reward: -0.2860
# [DEBUG] Step Reward: -8.9630, Action Penalty: 0.2775, Total Reward: -9.2405
# [DEBUG] Step Reward: -0.4025, Action Penalty: 0.2026, Total Reward: -0.6051
# [DEBUG] Step Reward: 2.7767, Action Penalty: 0.2362, Total Reward: 2.5406
# [DEBUG] Step Reward: -3.6007, Action Penalty: 0.3756, Total Reward: -3.9762
# [DEBUG] Step Reward: -1.4689, Action Penalty: 0.4447, Total Reward: -1.9136
# [DEBUG] Step Reward: 0.2846, Action Penalty: 0.4119, Total Reward: -0.1273
# [DEBUG] Step Reward: 2.3622, Action Penalty: 0.2484, Total Reward: 2.1137
# [DEBUG] Step Reward: -7.2361, Action Penalty: 0.2041, Total Reward: -7.4401
# [DEBUG] Step Reward: -0.3861, Action Penalty: 0.3063, Total Reward: -0.6925
# [DEBUG] Step Reward: 2.8293, Action Penalty: 0.3109, Total Reward: 2.5184
# [DEBUG] Step Reward: -4.6427, Action Penalty: 0.2285, Total Reward: -4.8712
# [DEBUG] Step Reward: 2.4454, Action Penalty: 0.2024, Total Reward: 2.2430
# [DEBUG] Step Reward: 7.2967, Action Penalty: 0.2490, Total Reward: 7.0477
# [DEBUG] Step Reward: 4.4293, Action Penalty: 0.2442, Total Reward: 4.1851
# [DEBUG] Step Reward: -4.7531, Action Penalty: 0.3013, Total Reward: -5.0544
# [DEBUG] Step Reward: -13.5592, Action Penalty: 0.3051, Total Reward: -13.8644
# [DEBUG] Step Reward: 3.7354, Action Penalty: 0.3816, Total Reward: 3.3538
# [DEBUG] Step Reward: -12.1254, Action Penalty: 0.3380, Total Reward: -12.4634
# [DEBUG] Step Reward: -1.4552, Action Penalty: 0.3385, Total Reward: -1.7937
# [DEBUG] Step Reward: 10.8792, Action Penalty: 0.3522, Total Reward: 10.5270
# [DEBUG] Step Reward: -15.2803, Action Penalty: 0.2178, Total Reward: -15.4981
# [DEBUG] Step Reward: -0.1534, Action Penalty: 0.3595, Total Reward: -0.5128
# [DEBUG] Step Reward: 2.6438, Action Penalty: 0.2497, Total Reward: 2.3941
# [DEBUG] Step Reward: 12.9917, Action Penalty: 0.3649, Total Reward: 12.6268
# [DEBUG] Step Reward: -16.0127, Action Penalty: 0.1977, Total Reward: -16.2104
# [DEBUG] Step Reward: 0.6334, Action Penalty: 0.3303, Total Reward: 0.3031
# [DEBUG] Step Reward: -9.9768, Action Penalty: 0.3346, Total Reward: -10.3114
# [DEBUG] Step Reward: -0.0993, Action Penalty: 0.3310, Total Reward: -0.4303
# [DEBUG] Step Reward: -8.1494, Action Penalty: 0.3304, Total Reward: -8.4798
# [DEBUG] Step Reward: -5.3341, Action Penalty: 0.3058, Total Reward: -5.6399
# [DEBUG] Step Reward: 7.8126, Action Penalty: 0.4004, Total Reward: 7.4122
# [DEBUG] Step Reward: -1.4069, Action Penalty: 0.3154, Total Reward: -1.7223
# [DEBUG] Step Reward: 8.9557, Action Penalty: 0.2309, Total Reward: 8.7248
# [DEBUG] Step Reward: -15.9535, Action Penalty: 0.4445, Total Reward: -16.3980
# [DEBUG] Step Reward: -3.0633, Action Penalty: 0.4114, Total Reward: -3.4747
# [DEBUG] Step Reward: 0.8000, Action Penalty: 0.2306, Total Reward: 0.5695
# [DEBUG] Step Reward: 12.4724, Action Penalty: 0.2137, Total Reward: 12.2587
# [DEBUG] Step Reward: -0.8309, Action Penalty: 0.2975, Total Reward: -1.1283
# [DEBUG] Step Reward: 1.8262, Action Penalty: 0.2803, Total Reward: 1.5459
# [DEBUG] Step Reward: 7.5467, Action Penalty: 0.1126, Total Reward: 7.4341
# [DEBUG] Step Reward: 9.0859, Action Penalty: 0.1989, Total Reward: 8.8870
# [DEBUG] Step Reward: -2.9714, Action Penalty: 0.3800, Total Reward: -3.3514
# [DEBUG] Step Reward: -3.1507, Action Penalty: 0.2241, Total Reward: -3.3748
# [DEBUG] Step Reward: 4.3245, Action Penalty: 0.1825, Total Reward: 4.1420
# [DEBUG] Step Reward: -8.1794, Action Penalty: 0.2928, Total Reward: -8.4722
# [DEBUG] Step Reward: 1.8824, Action Penalty: 0.1454, Total Reward: 1.7370
# [DEBUG] Step Reward: 4.6634, Action Penalty: 0.2685, Total Reward: 4.3949
# [DEBUG] Step Reward: -4.8174, Action Penalty: 0.3757, Total Reward: -5.1931
# [DEBUG] Step Reward: -10.6281, Action Penalty: 0.4596, Total Reward: -11.0877
# [DEBUG] Step Reward: -12.9264, Action Penalty: 0.4365, Total Reward: -13.3628
# [DEBUG] Step Reward: -12.1517, Action Penalty: 0.3526, Total Reward: -12.5043
# [DEBUG] Step Reward: -2.5139, Action Penalty: 0.4171, Total Reward: -2.9310
# [DEBUG] Step Reward: 5.5607, Action Penalty: 0.3989, Total Reward: 5.1618
# [DEBUG] Step Reward: -10.1116, Action Penalty: 0.3373, Total Reward: -10.4489
# [DEBUG] Step Reward: 0.3840, Action Penalty: 0.3449, Total Reward: 0.0391
# [DEBUG] Step Reward: 12.3609, Action Penalty: 0.1389, Total Reward: 12.2220
# [DEBUG] Step Reward: 1.0406, Action Penalty: 0.3112, Total Reward: 0.7294
# [DEBUG] Step Reward: 4.2344, Action Penalty: 0.3403, Total Reward: 3.8941
# [DEBUG] Step Reward: 8.9711, Action Penalty: 0.3348, Total Reward: 8.6363
# [DEBUG] Step Reward: 0.8771, Action Penalty: 0.3584, Total Reward: 0.5187
# [DEBUG] Step Reward: -5.3815, Action Penalty: 0.3023, Total Reward: -5.6838
# ...
# [DEBUG] Step Reward: 2.1301, Action Penalty: 0.2995, Total Reward: 1.8306
# [DEBUG] Step Reward: 0.9880, Action Penalty: 0.2833, Total Reward: 0.7048
# [DEBUG] Step Reward: 0.5743, Action Penalty: 0.3794, Total Reward: 0.1948
# [DEBUG] Step Reward: 0.4334, Action Penalty: 0.4251, Total Reward: 0.0084
# [DEBUG] Step Reward: 0.7264, Action Penalty: 0.4147, Total Reward: 0.3117
# [DEBUG] Step Reward: -1.6119, Action Penalty: 0.3733, Total Reward: -1.9852
# [DEBUG] Step Reward: -0.2365, Action Penalty: 0.3529, Total Reward: -0.5895
# [DEBUG] Step Reward: -1.0516, Action Penalty: 0.5139, Total Reward: -1.5655
# [DEBUG] Step Reward: 1.4226, Action Penalty: 0.2527, Total Reward: 1.1699
# [DEBUG] Step Reward: -1.6051, Action Penalty: 0.4783, Total Reward: -2.0834
# [DEBUG] Step Reward: 0.5061, Action Penalty: 0.2312, Total Reward: 0.2749
# [DEBUG] Step Reward: -1.9513, Action Penalty: 0.3181, Total Reward: -2.2693
# [DEBUG] Step Reward: -0.5576, Action Penalty: 0.6383, Total Reward: -1.1959
# [DEBUG] Step Reward: -1.2389, Action Penalty: 0.2845, Total Reward: -1.5235
# [DEBUG] Step Reward: 0.3409, Action Penalty: 0.4660, Total Reward: -0.1251
# [DEBUG] Step Reward: -1.9261, Action Penalty: 0.4248, Total Reward: -2.3508
# [DEBUG] Step Reward: -1.3628, Action Penalty: 0.4252, Total Reward: -1.7880
# [DEBUG] Step Reward: -0.6465, Action Penalty: 0.1701, Total Reward: -0.8166
# [DEBUG] Step Reward: 1.0074, Action Penalty: 0.2105, Total Reward: 0.7968
# [DEBUG] Step Reward: 0.1189, Action Penalty: 0.3380, Total Reward: -0.2192
# [DEBUG] Step Reward: -2.8455, Action Penalty: 0.3729, Total Reward: -3.2183
# [DEBUG] Step Reward: -1.7223, Action Penalty: 0.4447, Total Reward: -2.1670
# [DEBUG] Step Reward: -4.5764, Action Penalty: 0.2568, Total Reward: -4.8332
# [DEBUG] Step Reward: -8.6108, Action Penalty: 0.4792, Total Reward: -9.0900
# [DEBUG] Step Reward: 0.6709, Action Penalty: 0.3044, Total Reward: 0.3665
# [DEBUG] Step Reward: -3.2271, Action Penalty: 0.3609, Total Reward: -3.5879
# [DEBUG] Step Reward: 8.9489, Action Penalty: 0.6073, Total Reward: 8.3416
# [DEBUG] Step Reward: -0.6228, Action Penalty: 0.3068, Total Reward: -0.9296
# [DEBUG] Step Reward: -4.3025, Action Penalty: 0.3259, Total Reward: -4.6284
# [DEBUG] Step Reward: -0.3655, Action Penalty: 0.3370, Total Reward: -0.7025
# [DEBUG] Step Reward: -8.2702, Action Penalty: 0.4127, Total Reward: -8.6829
# [DEBUG] Step Reward: 3.6884, Action Penalty: 0.3636, Total Reward: 3.3248
# [DEBUG] Step Reward: 8.0071, Action Penalty: 0.2850, Total Reward: 7.7221
# [DEBUG] Step Reward: 3.1997, Action Penalty: 0.4805, Total Reward: 2.7193
# [DEBUG] Step Reward: -0.1258, Action Penalty: 0.1447, Total Reward: -0.2705
# [DEBUG] Step Reward: -4.1531, Action Penalty: 0.3791, Total Reward: -4.5322
# [DEBUG] Step Reward: -0.3176, Action Penalty: 0.2193, Total Reward: -0.5369
# [DEBUG] Step Reward: -0.2219, Action Penalty: 0.4699, Total Reward: -0.6919
# [DEBUG] Step Reward: 3.9155, Action Penalty: 0.2401, Total Reward: 3.6755
# [DEBUG] Step Reward: 1.4475, Action Penalty: 0.4356, Total Reward: 1.0119
# [DEBUG] Step Reward: 2.8981, Action Penalty: 0.3068, Total Reward: 2.5913
# [DEBUG] Step Reward: 3.8281, Action Penalty: 0.4462, Total Reward: 3.3819
# [DEBUG] Step Reward: -2.8298, Action Penalty: 0.3415, Total Reward: -3.1713
# [DEBUG] Step Reward: 1.2013, Action Penalty: 0.4325, Total Reward: 0.7688
# [DEBUG] Step Reward: 0.1139, Action Penalty: 0.4026, Total Reward: -0.2887
# [DEBUG] Step Reward: -0.7840, Action Penalty: 0.3814, Total Reward: -1.1655
# [DEBUG] Step Reward: 1.8250, Action Penalty: 0.2580, Total Reward: 1.5670
# [DEBUG] Step Reward: 2.9918, Action Penalty: 0.2757, Total Reward: 2.7161
# [DEBUG] Step Reward: 3.1289, Action Penalty: 0.2257, Total Reward: 2.9031
# [DEBUG] Step Reward: -5.3371, Action Penalty: 0.3608, Total Reward: -5.6979
# [DEBUG] Step Reward: 1.7625, Action Penalty: 0.4072, Total Reward: 1.3553
# [DEBUG] Step Reward: 7.2917, Action Penalty: 0.4231, Total Reward: 6.8686
# [DEBUG] Step Reward: -1.3390, Action Penalty: 0.3686, Total Reward: -1.7075
# [DEBUG] Step Reward: 1.4207, Action Penalty: 0.4238, Total Reward: 0.9969
# [DEBUG] Step Reward: 2.9878, Action Penalty: 0.3733, Total Reward: 2.6145
# [DEBUG] Step Reward: -1.7780, Action Penalty: 0.4523, Total Reward: -2.2303
# [DEBUG] Step Reward: -5.5049, Action Penalty: 0.3080, Total Reward: -5.8130
# [DEBUG] Step Reward: 1.7902, Action Penalty: 0.5001, Total Reward: 1.2901
# [DEBUG] Step Reward: 7.5590, Action Penalty: 0.2751, Total Reward: 7.2839
# [DEBUG] Step Reward: 1.7083, Action Penalty: 0.2949, Total Reward: 1.4134
# [DEBUG] Step Reward: 0.0284, Action Penalty: 0.3489, Total Reward: -0.3205
# [DEBUG] Step Reward: -1.3986, Action Penalty: 0.3956, Total Reward: -1.7943
# [DEBUG] Step Reward: -1.4700, Action Penalty: 0.3783, Total Reward: -1.8482
# [DEBUG] Step Reward: 2.5871, Action Penalty: 0.4453, Total Reward: 2.1417
# [DEBUG] Step Reward: 1.2139, Action Penalty: 0.4199, Total Reward: 0.7940
# [DEBUG] Step Reward: -9.5472, Action Penalty: 0.2860, Total Reward: -9.8332
# [DEBUG] Step Reward: 4.6954, Action Penalty: 0.3801, Total Reward: 4.3153
# [DEBUG] Step Reward: -0.9898, Action Penalty: 0.4430, Total Reward: -1.4328
# [DEBUG] Step Reward: -9.8045, Action Penalty: 0.3563, Total Reward: -10.1607
# [DEBUG] Step Reward: 3.8371, Action Penalty: 0.3937, Total Reward: 3.4435
# [DEBUG] Step Reward: -3.7606, Action Penalty: 0.2795, Total Reward: -4.0402
# [DEBUG] Step Reward: 4.2535, Action Penalty: 0.4651, Total Reward: 3.7884
# [DEBUG] Step Reward: 2.8887, Action Penalty: 0.2749, Total Reward: 2.6138
# [DEBUG] Step Reward: 3.3342, Action Penalty: 0.3494, Total Reward: 2.9848
# [DEBUG] Step Reward: 0.9651, Action Penalty: 0.3121, Total Reward: 0.6530
# [DEBUG] Step Reward: -3.3422, Action Penalty: 0.2822, Total Reward: -3.6244
# [DEBUG] Step Reward: 0.7865, Action Penalty: 0.4178, Total Reward: 0.3686
# [DEBUG] Step Reward: 2.2761, Action Penalty: 0.4544, Total Reward: 1.8217
# [DEBUG] Step Reward: -4.3799, Action Penalty: 0.3194, Total Reward: -4.6993
# [DEBUG] Step Reward: 1.0197, Action Penalty: 0.2990, Total Reward: 0.7206
# [DEBUG] Step Reward: 3.0248, Action Penalty: 0.2620, Total Reward: 2.7628
# [DEBUG] Step Reward: 0.6974, Action Penalty: 0.2934, Total Reward: 0.4039
# [DEBUG] Step Reward: -0.6176, Action Penalty: 0.3530, Total Reward: -0.9706
# [DEBUG] Step Reward: -3.9816, Action Penalty: 0.4409, Total Reward: -4.4224
# [DEBUG] Step Reward: -0.7426, Action Penalty: 0.4716, Total Reward: -1.2142
# [DEBUG] Step Reward: 3.1826, Action Penalty: 0.3852, Total Reward: 2.7975
# Process Learner-17:
# Process Worker-19:
# Process EvaluatorProc-20:
# Process Worker-18:
# Traceback (most recent call last):
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py", line 296, in run
#     worker_id, buffer_items, last_state = self.recv_pipe.recv()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py", line 447, in run
#     actor, steps, exp_r, logging_tuple = self.pipe0.recv()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py", line 410, in run
#     buffer_items = agent.explore_env(env, horizon_len)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentBase.py", line 74, in explore_env
#     return self._explore_one_env(env=env, horizon_len=horizon_len)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentPPO.py", line 60, in _explore_one_env
#     action, logprob = [t[0] for t in self.explore_action(state)]
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentPPO.py", line 132, in explore_action
#     actions, logprobs = self.act.get_action(state)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentPPO.py", line 370, in get_action
#     action_avg = self.net(state)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/torch/nn/modules/activation.py", line 682, in forward
#     return F.gelu(input, approximate=self.approximate)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py", line 410, in run
#     buffer_items = agent.explore_env(env, horizon_len)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentBase.py", line 74, in explore_env
#     return self._explore_one_env(env=env, horizon_len=horizon_len)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/agents/AgentPPO.py", line 67, in _explore_one_env
#     ary_state, reward, terminal, truncate, _ = env.step(ary_action)
#   File "/Users/ll/Library/CloudStorage/OneDrive-个人/Class/RL&Autonomous Driving/project/FinRL/RL-Project_FinRL/env_wrapper/ppo_env_wrapper.py", line 203, in step
#     res = self.env.step(action)
#   File "/Users/ll/Library/CloudStorage/OneDrive-个人/Class/RL&Autonomous Driving/project/FinRL/finrl/meta/env_stock_trading/env_stocktrading.py", line 352, in step
#     self.state = self._update_state()
#   File "/Users/ll/Library/CloudStorage/OneDrive-个人/Class/RL&Autonomous Driving/project/FinRL/finrl/meta/env_stock_trading/env_stocktrading.py", line 473, in _update_state
#     + self.data.close.values.tolist()
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/generic.py", line 6298, in __getattr__
#     return self[name]
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/frame.py", line 4078, in __getitem__
#     return self._get_item_cache(key)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/frame.py", line 4639, in _get_item_cache
#     res = self._ixs(loc, axis=1)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/frame.py", line 4011, in _ixs
#     result = self._box_col_values(col_mgr, i)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/frame.py", line 4616, in _box_col_values
#     obj = self._constructor_sliced_from_mgr(values, axes=values.axes)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/frame.py", line 679, in _constructor_sliced_from_mgr
#     ser = Series._from_mgr(mgr, axes)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/generic.py", line 357, in _from_mgr
#     NDFrame.__init__(obj, mgr)
#   File "/Users/ll/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/pandas/core/generic.py", line 280, in __init__
#     object.__setattr__(self, "_mgr", data)
# KeyboardInterrupt
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 42
#      38 print("="*80 + "\n")
#      40 print("[-->] Starting PPO Agent Training...")
# ---> 42 train_agent(args)
#      44 print("\n" + "="*80)
#      45 print("[✓] Training completed successfully!")
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py:31, in train_agent(args, if_single_process)
#      29 elif len(args.learner_gpu_ids) == 0:
#      30     print(f"| train_agent_multiprocessing() with GPU_ID {args.gpu_id}", flush=True)
# ---> 31     train_agent_multiprocessing(args)
#      32 elif len(args.learner_gpu_ids) != 0:
#      33     print(f"| train_agent_multiprocessing_multi_gpu() with GPU_ID {args.learner_gpu_ids}", flush=True)
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py:162, in train_agent_multiprocessing(args)
#     160 process_list = [learner, *workers, evaluator]
#     161 [process.start() for process in process_list]
# --> 162 [process.join() for process in process_list]
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/site-packages/elegantrl/train/run.py:162, in <listcomp>(.0)
#     160 process_list = [learner, *workers, evaluator]
#     161 [process.start() for process in process_list]
# --> 162 [process.join() for process in process_list]
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/popen_forkserver.py:65, in Popen.poll(self, flag)
#      63 from multiprocessing.connection import wait
#      64 timeout = 0 if flag == os.WNOHANG else None
# ---> 65 if not wait([self.sentinel], timeout):
#      66     return None
#      67 try:
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/opt/anaconda3/envs/finrl/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

def calculate_metrics(df, column_name='account_value'):
    """Calculate key performance metrics"""
    daily_return = df[column_name].pct_change().dropna()

    cum_return = (df[column_name].iloc[-1] / df[column_name].iloc[0]) - 1

    if daily_return.std() != 0:
        sharpe_ratio = (252 ** 0.5) * (daily_return.mean() / daily_return.std())
    else:
        sharpe_ratio = 0

    rolling_max = df[column_name].cummax()
    drawdown = (df[column_name] - rolling_max) / rolling_max
    max_drawdown = drawdown.min()

    return cum_return, sharpe_ratio, max_drawdown


def ppo_test(result_file):
    """Test PPO strategy performance and compare with benchmark"""

    try:
        df = pd.read_csv(result_file)
        df['date'] = pd.to_datetime(df['date'])
        df = df.drop_duplicates(subset=['date']).sort_values('date').reset_index(drop=True)

        start_date = df['date'].iloc[0].strftime('%Y-%m-%d')
        end_date = df['date'].iloc[-1].strftime('%Y-%m-%d')
        initial_capital = df['account_value'].iloc[0]

        print(f"\n[STEP 7] Performance Analysis")
        print(f"[*] Successfully loaded PPO trading records!")
        print(f"    Testing period: {start_date} to {end_date}")
        print(f"    Test duration: {len(df)} trading days")
        print(f"[*] Downloading Dow Jones Index as benchmark...")

        # Download benchmark data
        benchmark = yf.download("^DJI", start=start_date, end=end_date, progress=False)

        if isinstance(benchmark.columns, pd.MultiIndex):
            benchmark.columns = benchmark.columns.get_level_values(0)

        benchmark = benchmark.reset_index()

        # Unify date column name
        if 'Date' not in benchmark.columns and 'index' in benchmark.columns:
            benchmark = benchmark.rename(columns={'index': 'Date'})

        benchmark['Date'] = pd.to_datetime(benchmark['Date'])

        # Merge tables
        df = pd.merge(df, benchmark[['Date', 'Close']], left_on='date', right_on='Date', how='left')
        df['Close'] = df['Close'].ffill()  # Fill missing weekend/holiday data

        df['benchmark_value'] = (df['Close'] / df['Close'].iloc[0]) * initial_capital

        # Calculate metrics
        ppo_ret, ppo_sharpe, ppo_mdd = calculate_metrics(df, 'account_value')
        bm_ret, bm_sharpe, bm_mdd = calculate_metrics(df, 'benchmark_value')

        print("\n" + "=" * 80)
        print(f"{'🚀 PPO Agent Stock Trading Performance Report 🚀':^80}")
        print("=" * 80)
        print(f"{'Metric':<34} {'PPO Strategy':>22} {'Benchmark':>22}")
        print("-" * 80)
        print(f"{'Cumulative Return':<34} {ppo_ret*100:>21.2f}% {bm_ret*100:>21.2f}%")
        print(f"{'Annualized Sharpe Ratio':<34} {ppo_sharpe:>22.4f} {bm_sharpe:>22.4f}")
        print(f"{'Maximum Drawdown':<34} {ppo_mdd*100:>21.2f}% {bm_mdd*100:>21.2f}%")
        print("=" * 80)

        # Calculate outperformance
        excess_return = (ppo_ret - bm_ret) * 100
        sharpe_diff = ppo_sharpe - bm_sharpe
        dd_improvement = (bm_mdd - ppo_mdd) * 100

        print(f"{'Excess Return':<34} {excess_return:>21.2f}%")
        print(f"{'Sharpe Ratio Difference':<34} {sharpe_diff:>22.4f}")
        print(f"{'Max Drawdown Improvement':<34} {dd_improvement:>21.2f}%")
        print("=" * 80 + "\n")

        # Create visualization
        plt.figure(figsize=(15, 8))
        plt.style.use('seaborn-v0_8-darkgrid')

        plt.plot(df['date'], df['account_value'], label='PPO Agent Portfolio', 
                color='#2E86AB', linewidth=2.5)
        plt.plot(df['date'], df['benchmark_value'], label='Dow Jones Index (Benchmark)', 
                color='#A23B72', linewidth=1.5, linestyle='--', alpha=0.8)

        plt.title('Proximal Policy Optimization (PPO) Stock Trading Performance', 
                 fontsize=16, fontweight='bold', pad=20)
        plt.xlabel('Date', fontsize=12, fontweight='bold')
        plt.ylabel('Portfolio Value ($)', fontsize=12, fontweight='bold')
        plt.grid(True, alpha=0.3)

        textstr = '\n'.join((
            r'$\bf{PPO\ Strategy}$',
            f'Return: {ppo_ret * 100:.2f}%',
            f'Sharpe: {ppo_sharpe:.3f}',
            f'Max DD: {ppo_mdd * 100:.2f}%',
            '',
            r'$\bf{Benchmark}$',
            f'Return: {bm_ret * 100:.2f}%',
            f'Sharpe: {bm_sharpe:.3f}',
            f'Max DD: {bm_mdd * 100:.2f}%',
            '',
            r'$\bf{Outperformance}$',
            f'Excess Return: {excess_return:.2f}%',
            f'Sharpe Diff: {sharpe_diff:.3f}'
        ))
        props = dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='gray', linewidth=1.5)
        plt.gca().text(0.02, 0.98, textstr, transform=plt.gca().transAxes, fontsize=9.5,
                       verticalalignment='top', bbox=props, family='monospace')

        plt.legend(loc='lower right', fontsize=11, framealpha=0.95)
        plt.tight_layout()

        # Save figure
        fig_path = 'ppo_backtest_performance.png'
        plt.savefig(fig_path, dpi=300, bbox_inches='tight')
        print(f"[✓] Equity curve visualization saved to '{fig_path}'!")
        
        plt.show()

    except Exception as e:
        print(f"[ERROR] An error occurred during testing: {e}")
        import traceback
        traceback.print_exc()


# Run PPO test
test_result_file1 = "./logs/stock/ppo_test_results1.csv"  # Update with actual test result file path
test_result_file2 = "./logs/stock/ppo_test_results2.csv"  # Update with actual test result file path
ppo_test(test_result_file1)
ppo_test(test_result_file2)
print("[✓] PPO Test Complete!")
# Out:
# [STEP 7] Performance Analysis
# [*] Successfully loaded PPO trading records!
#     Testing period: 2023-10-25 to 2023-11-14
#     Test duration: 15 trading days
# [*] Downloading Dow Jones Index as benchmark...
# YF.download() has changed argument auto_adjust default to True
#
# ================================================================================
#                  🚀 PPO Agent Stock Trading Performance Report 🚀
# ================================================================================
# Metric                                       PPO Strategy              Benchmark
# --------------------------------------------------------------------------------
# Cumulative Return                                   3.53%                  3.94%
# Annualized Sharpe Ratio                            6.6434                 5.3498
# Maximum Drawdown                                   -0.73%                 -1.87%
# ================================================================================
# Excess Return                                      -0.41%
# Sharpe Ratio Difference                            1.2936
# Max Drawdown Improvement                           -1.14%
# ================================================================================
#
# [✓] Equity curve visualization saved to 'ppo_backtest_performance.png'!
#
# [STEP 7] Performance Analysis
# [*] Successfully loaded PPO trading records!
#     Testing period: 2023-11-15 to 2023-11-22
#     Test duration: 6 trading days
# [*] Downloading Dow Jones Index as benchmark...
#
# ================================================================================
#                  🚀 PPO Agent Stock Trading Performance Report 🚀
# ================================================================================
# Metric                                       PPO Strategy              Benchmark
# --------------------------------------------------------------------------------
# Cumulative Return                                   0.08%                  0.28%
# Annualized Sharpe Ratio                            3.3274                 2.8993
# Maximum Drawdown                                   -0.10%                 -0.18%
# ================================================================================
# Excess Return                                      -0.20%
# Sharpe Ratio Difference                            0.4282
# Max Drawdown Improvement                           -0.08%
# ================================================================================
#
# [✓] Equity curve visualization saved to 'ppo_backtest_performance.png'!
# [✓] PPO Test Complete!

# %%
# Visualization: Plot Test Results with Benchmark
import matplotlib.pyplot as plt

def plot_test_results(result_file):
    """Plot PPO test results against benchmark"""
    try:
        
        if not os.path.exists(result_file):
            print(f"[!] Test results file not found: {result_file}")
            print("    Please run the training cell (cell 7) first")
            return
        
        df = pd.read_csv(result_file)
        df['date'] = pd.to_datetime(df['date'])
        df = df.drop_duplicates(subset=['date']).sort_values('date').reset_index(drop=True)
        
        start_date = df['date'].iloc[0].strftime('%Y-%m-%d')
        end_date = df['date'].iloc[-1].strftime('%Y-%m-%d')
        initial_capital = df['account_value'].iloc[0]
        
        print(f"[*] Loading PPO test results...")
        print(f"    Test period: {start_date} to {end_date}")
        print(f"    Trading days: {len(df)}")
        print(f"[*] Downloading Dow Jones benchmark data...")
        
        # Download benchmark
        benchmark = yf.download("^DJI", start=start_date, end=end_date, progress=False)
        
        if isinstance(benchmark.columns, pd.MultiIndex):
            benchmark.columns = benchmark.columns.get_level_values(0)
        
        benchmark = benchmark.reset_index()
        
        if 'Date' not in benchmark.columns and 'index' in benchmark.columns:
            benchmark = benchmark.rename(columns={'index': 'Date'})
        
        benchmark['Date'] = pd.to_datetime(benchmark['Date'])
        
        # Merge with benchmark
        df = pd.merge(df, benchmark[['Date', 'Close']], left_on='date', right_on='Date', how='left')
        df['Close'] = df['Close'].ffill()
        df['benchmark_value'] = (df['Close'] / df['Close'].iloc[0]) * initial_capital
        
        # Calculate metrics
        ppo_ret = (df['account_value'].iloc[-1] / df['account_value'].iloc[0] - 1) * 100
        bm_ret = (df['benchmark_value'].iloc[-1] / df['benchmark_value'].iloc[0] - 1) * 100
        
        ppo_daily = df['account_value'].pct_change().dropna()
        bm_daily = df['benchmark_value'].pct_change().dropna()
        
        ppo_sharpe = (252 ** 0.5) * (ppo_daily.mean() / ppo_daily.std()) if ppo_daily.std() != 0 else 0
        bm_sharpe = (252 ** 0.5) * (bm_daily.mean() / bm_daily.std()) if bm_daily.std() != 0 else 0
        
        ppo_max = df['account_value'].cummax()
        ppo_dd = ((df['account_value'] - ppo_max) / ppo_max).min() * 100
        
        bm_max = df['benchmark_value'].cummax()
        bm_dd = ((df['benchmark_value'] - bm_max) / bm_max).min() * 100
        
        # Create visualization
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 8))
        
        # Plot 1: Portfolio Value Comparison
        ax1.plot(df['date'], df['account_value'], label='PPO Agent Portfolio', 
                color='#2E86AB', linewidth=2.5)
        ax1.plot(df['date'], df['benchmark_value'], label='Dow Jones Index (Benchmark)', 
                color='#A23B72', linewidth=2, linestyle='--', alpha=0.8)
        
        ax1.set_title('PPO Agent Test Period Performance vs Benchmark', 
                     fontsize=16, fontweight='bold', pad=15)
        ax1.set_xlabel('Date', fontsize=12, fontweight='bold')
        ax1.set_ylabel('Portfolio Value ($)', fontsize=12, fontweight='bold')
        ax1.grid(True, alpha=0.3)
        ax1.legend(loc='lower right', fontsize=11, framealpha=0.95)
        
        # Add metrics text box
        textstr = '\n'.join((
            r'$\bf{PPO\ Strategy}$',
            f'Return: {ppo_ret:.2f}%',
            f'Sharpe: {ppo_sharpe:.3f}',
            f'Max DD: {ppo_dd:.2f}%',
            '',
            r'$\bf{Benchmark}$',
            f'Return: {bm_ret:.2f}%',
            f'Sharpe: {bm_sharpe:.3f}',
            f'Max DD: {bm_dd:.2f}%'
        ))
        props = dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='gray', linewidth=1.5)
        ax1.text(0.02, 0.98, textstr, transform=ax1.transAxes, fontsize=10,
                verticalalignment='top', bbox=props, family='monospace')
        
        # Plot 2: Daily Returns Comparison
        ppo_returns = df['account_value'].pct_change() * 100
        bm_returns = df['benchmark_value'].pct_change() * 100
        
        ax2.plot(df['date'], ppo_returns, label='PPO Daily Return', 
                color='#2E86AB', linewidth=1.5, alpha=0.7)
        ax2.plot(df['date'], bm_returns, label='Benchmark Daily Return', 
                color='#A23B72', linewidth=1.5, alpha=0.7, linestyle='--')
        ax2.axhline(y=0, color='black', linestyle='-', linewidth=0.5, alpha=0.5)
        
        ax2.set_title('Daily Returns Comparison', fontsize=14, fontweight='bold', pad=10)
        ax2.set_xlabel('Date', fontsize=12, fontweight='bold')
        ax2.set_ylabel('Daily Return (%)', fontsize=12, fontweight='bold')
        ax2.grid(True, alpha=0.3)
        ax2.legend(loc='lower right', fontsize=10, framealpha=0.95)
        
        plt.tight_layout()
        
        # Save figure
        fig_path = 'ppo_test_analysis.png'
        plt.savefig(fig_path, dpi=300, bbox_inches='tight')
        print(f"\n[✓] Test results visualization saved to '{fig_path}'!")
        
        plt.show()
        
        # Print summary
        print("\n" + "="*80)
        print(f"{'Test Period Performance Summary':^80}")
        print("="*80)
        print(f"{'Metric':<30} {'PPO Agent':>20} {'Benchmark':>20}")
        print("-"*80)
        print(f"{'Cumulative Return':<30} {ppo_ret:>19.2f}% {bm_ret:>19.2f}%")
        print(f"{'Annualized Sharpe Ratio':<30} {ppo_sharpe:>20.3f} {bm_sharpe:>20.3f}")
        print(f"{'Maximum Drawdown':<30} {ppo_dd:>19.2f}% {bm_dd:>19.2f}%")
        print(f"{'Excess Return':<30} {(ppo_ret - bm_ret):>19.2f}%")
        print("="*80)
        
    except Exception as e:
        print(f"[ERROR] Failed to plot test results: {e}")
        import traceback
        traceback.print_exc()

# Run visualization
print("\n[STEP 9] Test Results Visualization")
print("="*80)

result_file1 = "./logs/stock/ppo_test_results1.csv"  
result_file2 = "./logs/stock/ppo_test_results2.csv" 

plot_test_results(result_file1)
plot_test_results(result_file2)
# Out:
# [STEP 9] Test Results Visualization
# ================================================================================
# [*] Loading PPO test results...
#     Test period: 2023-10-25 to 2023-11-14
#     Trading days: 15
# [*] Downloading Dow Jones benchmark data...
#
# [✓] Test results visualization saved to 'ppo_test_analysis.png'!
#
# ================================================================================
#                         Test Period Performance Summary
# ================================================================================
# Metric                                    PPO Agent            Benchmark
# --------------------------------------------------------------------------------
# Cumulative Return                             3.53%                3.94%
# Annualized Sharpe Ratio                       6.643                5.350
# Maximum Drawdown                             -0.73%               -1.87%
# Excess Return                                -0.41%
# ================================================================================
# [*] Loading PPO test results...
#     Test period: 2023-11-15 to 2023-11-22
#     Trading days: 6
# [*] Downloading Dow Jones benchmark data...
#
# [✓] Test results visualization saved to 'ppo_test_analysis.png'!
#
# ================================================================================
#                         Test Period Performance Summary
# ================================================================================
# Metric                                    PPO Agent            Benchmark
# --------------------------------------------------------------------------------
# Cumulative Return                             0.08%                0.28%
# Annualized Sharpe Ratio                       3.327                2.899
# Maximum Drawdown                             -0.10%               -0.18%
# Excess Return                                -0.20%
# ================================================================================
